# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline

# %%
# read the csv file
data=pd.read_csv('used_cars_data.csv')

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
# check the head of data set
data.head(5)
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
# check the tail of data set
data.tail(5)
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price  Price
# ...

# %%
# check the shape
data.shape
# Out:
# (7253, 14)

# %%
# check the info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
# find if there is any null values
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
# remove the units from various columns

# %%
# zcdb = ZipCodeDatabase()
# zipcode = zcdb[54115]
# >>> zipcode.zip
# u'54115'
# print (zipcode.city)
# u'De Pere'
# >>> zipcode.state
# u'WI'
# Out:
# Start downloading data for simple zipcode database, total size 9MB ...
#   1 MB finished ...
#   2 MB finished ...
#   3 MB finished ...
#   4 MB finished ...
#   5 MB finished ...
#   6 MB finished ...
#   7 MB finished ...
#   8 MB finished ...
#   9 MB finished ...
#   10 MB finished ...
#   Complete!

# %%
# convert engine to numeric

# %%
data[data['Engine'].isnull()].count()
# Out:
# S.No.                46
# Name                 46
# Location             46
# Year                 46
# Kilometers_Driven    46
# Fuel_Type            46
# Transmission         46
# Owner_Type           46
# Mileage              46
# Engine                0
# Power                 0
# Seats                 0
# New_Price             0
# Price                36
# dtype: int64

# %%
data[data['Engine'].str.endswith('CC')==True].count()
# so there are either NaaN or ends with CC(7207+46 null=7253)
# Out:
# S.No.                7207
# Name                 7207
# Location             7207
# Year                 7207
# Kilometers_Driven    7207
# Fuel_Type            7207
# Transmission         7207
# Owner_Type           7207
# Mileage              7205
# Engine               7207
# Power                7207
# Seats                7200
# New_Price            1006
# Price                5983
# dtype: int64

# %%
# convert engine to numeric by removing CC
def value_to_num(val):
    
    if isinstance(val, str):  # checks if `val` is a string        
        return float(val.replace('CC', '')) 
    else:  
        return np.nan

data['Engine'] = data['Engine'].apply(value_to_num)
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998.0
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582.0
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199.0
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248.0
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968.0
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
# convert Power to numeric
data[(data['Power'].str.endswith('bhp')==True)].count() 
# so there are either NaaN or ends with bhp
# Out:
# S.No.                7207
# Name                 7207
# Location             7207
# Year                 7207
# Kilometers_Driven    7207
# Fuel_Type            7207
# Transmission         7207
# Owner_Type           7207
# Mileage              7205
# Engine               7207
# Power                7207
# Seats                7200
# New_Price            1006
# Price                5983
# dtype: int64

# %%
# convert Power to numeric by removing bhp
def value_to_num(val):
    
    if isinstance(val, str):  # checks if `val` is a string        

        return float(val.replace('bhp', '')) 
    else:  
        return np.nan

data['Power'] = data['Power'].apply(value_to_num)
data.head()
# there are items with 'null bhp' which should be handled
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-366-cac1acb1721e> in <module>
#       8         return np.nan
#       9
# ---> 10 data['Power'] = data['Power'].apply(value_to_num)
#      11 data.head()
#      12 # there are items with 'null bhp' which should be handled
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-366-cac1acb1721e> in value_to_num(val)
#       4     if isinstance(val, str):  # checks if `val` is a string
#       5
# ...

# %%
# convert Power to numeric by removing bhp and null bhp
def value_to_num(val):
    if isinstance(val, str):# checks if `val` is a string        
        if (val.startswith('null')==False):  # checks if starts with 'null' as found entried with null bhp       
            return float(val.replace('bhp', '')) 
        else:
            np.nan
    else:  
        return np.nan

data['Power'] = data['Power'].apply(value_to_num)
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998.0
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582.0
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199.0
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248.0
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968.0
#
#     Power  Seats  New_Price  Price
# 0   58.16    5.0        NaN   1.75
# 1  126.20    5.0        NaN  12.50
# 2   88.70    5.0  8.61 Lakh   4.50
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   float64
#  10  Power              7078 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 793.4+ KB

# %%
# convert New Price to numeric by removing Lakh
# data[(data['New_Price'].str.endswith('bhp')==False) | (data['Power'].isnull())].count()
data[(data['New_Price'].str.endswith('Lakh')==False)]
# there are values ending with CR
# Out:
#       S.No.                                           Name    Location  Year  \
# 148     148                                 Audi RS5 Coupe      Mumbai  2013
# 327     327              Audi Q7 45 TDI Quattro Technology  Coimbatore  2017
# 489     489                  Mercedes-Benz GLS 350d 4MATIC        Pune  2017
# 1336   1336              Audi Q7 45 TDI Quattro Technology      Mumbai  2016
# 1505   1505                Land Rover Range Rover Sport SE       Kochi  2019
# 1885   1885           Mercedes-Benz GLS 350d Grand Edition       Delhi  2018
# 2056   2056                    BMW 7 Series 730Ld Eminence       Kochi  2015
# 2095   2095                       Mercedes-Benz SLC 43 AMG  Coimbatore  2019
# 2178   2178        Land Rover Discovery HSE Luxury 3.0 TD6      Mumbai  2017
# 2528   2528                Land Rover Discovery SE 3.0 TD6       Delhi  2016
# 3132   3132                           Porsche Cayenne Base       Kochi  2019
# ...

# %%
# convert New Price to numeric by removing Crore
def value_to_num(val):
    if isinstance(val, str):  # checks if `val` is a string        
        if (val.endswith('Lakh')==True):
            return float(val.replace('Lakh', '')) 
        else: 
            return float(val.replace('Cr', ''))*100 
    else:  
        return np.nan

data['New_Price'] = data['New_Price'].apply(value_to_num)
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998.0
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582.0
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199.0
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248.0
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968.0
#
#     Power  Seats  New_Price  Price
# 0   58.16    5.0        NaN   1.75
# 1  126.20    5.0        NaN  12.50
# 2   88.70    5.0       8.61   4.50
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   float64
#  10  Power              7078 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   float64
#  13  Price              6019 non-null   float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 793.4+ KB

# %%
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                 175
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
# convert Mileage to numeric by removing km/kg and kmpl
# data[(data['Mileage'].str.endswith('km/kg')==False)& (data['Mileage'].str.endswith('kmpl')==False)]
data[(data['Mileage'].str.endswith('km/kg')==True)| (data['Mileage'].str.endswith('kmpl')==True)]
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
# convert New Price to numeric by removing Lakh
def value_to_num(val):
    if isinstance(val, str):  # checks if `val` is a string        
        if (val.endswith('kmpl')==True):
            return float(val.replace('kmpl', '')) 
        else: 
            return float(val.replace('km/kg', ''))
    else:  
        return np.nan

data['Mileage'] = data['Mileage'].apply(value_to_num)
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#     Power  Seats  New_Price  Price
# 0   58.16    5.0        NaN   1.75
# 1  126.20    5.0        NaN  12.50
# 2   88.70    5.0       8.61   4.50
# ...

# %%
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                 175
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   float64
#  10  Power              7078 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   float64
#  13  Price              6019 non-null   float64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 793.4+ KB

# %%
# Get first name of cars in a new column
def get_first(val):
    if isinstance(val, str):  # checks if `val` is a string        
        return val.split()[0]
    else:  
        return np.nan

data['First_Name'] = data['Name'].apply(get_first)
data.head()
# data['First_Name']=data['Name'].str.split()[0]
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#     Power  Seats  New_Price  Price First_Name
# 0   58.16    5.0        NaN   1.75     Maruti
# 1  126.20    5.0        NaN  12.50    Hyundai
# ...

# %%
data['First_Name'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Honda', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini', 'Fiat', 'Jeep',
#        'Smart', 'Ambassador', 'Isuzu', 'ISUZU', 'Force', 'Bentley',
#        'Lamborghini', 'Hindustan', 'OpelCorsa'], dtype=object)

# %%
# Create list of cars based on where they are designed
mk_ind=['Maruti','Tata','Mahindra','Ambassador', 'Hindustan','Force']
mk_kor=['Hyundai']
mk_jpn=['Honda','Nissan','Toyota','Mitsubishi','Datsun','ISUZU','Isuzu']
mk_us=['Ford','Chevrolet','Jeep']
mk_eur=['Audi','Volkswagen','OpelCorsa','Jaguar','Fiat','Mercedes-Benz', 'BMW','Volvo','Skoda', 'Mini','Land','Porsche','Renault','Bentley','Lamborghini','Smart']

# %%
'Maruti'in (mk_ind)
# Out:
# True

# %%
# Assign continet/country where designed
def get_cont(val):
    if val in (mk_ind):
        return 'India'
    elif val in (mk_kor):  
        return 'Korea'
    elif val in (mk_jpn):  
        return 'Japan'
    elif val in (mk_us):  
        return 'USA'
    else:  
        return 'Europe'
data['Cont'] = data['First_Name'].apply(get_cont)
data.head(10)
# data['First_Name']=data['Name'].str.split()[0]
# Out:
#    S.No.                                 Name    Location  Year  \
# 0      0               Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                         Honda Jazz V     Chennai  2011
# 3      3                    Maruti Ertiga VDI     Chennai  2012
# 4      4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5      5      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6      6               Nissan Micra Diesel XV      Jaipur  2013
# 7      7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8      8  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9      9       Tata Indica Vista Quadrajet LS     Chennai  2012
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# ...

# %%
data[data['Price'].isnull()==True ].sort_values('Name')
# Out:
#       S.No.                         Name   Location  Year  Kilometers_Driven  \
# 6663   6663    Audi A3 35 TDI Attraction  Ahmedabad  2014              84004
# 6742   6742  Audi A3 35 TDI Premium Plus  Hyderabad  2015              52300
# 7238   7238              Audi A4 2.0 TDI  Hyderabad  2011              64000
# 7233   7233              Audi A4 2.0 TDI  Bangalore  2014              21143
# 7168   7168              Audi A4 2.0 TDI  Bangalore  2014              65475
# ...     ...                          ...        ...   ...                ...
# 6809   6809                 Volvo S80 D5      Delhi  2011              87000
# 6859   6859   Volvo V40 Cross Country D3    Chennai  2015              60000
# 6681   6681         Volvo XC60 D4 SUMMUM  Ahmedabad  2013              64000
# 6659   6659  Volvo XC90 2007-2015 D5 AWD      Delhi  2014              22230
# 6384   6384  Volvo XC90 2007-2015 D5 AWD  Bangalore  2016              70000
#
# ...

# %%
# Steps to create mean price of cars with same name, year, fuel type and transmission
data_price=data.groupby(['Name','Year','Fuel_Type','Transmission'], as_index=False)['Price'].mean()
# data_price_t=data.groupby(['Name'], as_index=False)['Price'].mean()
# data_price=data.groupby(['Name'], as_index=False)['Price'].mean()

# %%
# Steps to create mean price of cars with same name, year, fuel type and transmission
data=pd.merge(data,data_price,how='left',on=('Name','Year','Fuel_Type','Transmission'))
# data_upd_prc=pd.merge(data,data_price,how='left',on=('Name'))

# %%
# Assign mean price to price columsn which are null
for i in range(len(data)):
    
    if ((data.loc[i, 'Price_x']!=data.loc[i, 'Price_x'])&(data.loc[i, 'Price_y']==data.loc[i, 'Price_y'])):
        data.loc[i, 'Price_x']=data.loc[i, 'Price_y']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 7252
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   float64
#  10  Power              7078 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   float64
#  13  Price_x            6698 non-null   float64
#  14  First_Name         7253 non-null   object
#  15  Cont               7253 non-null   object
# ...

# %%
# Steps to create mean new price of cars with same name, year, fuel type and transmission
data_new_price=data.groupby(['Name','Year','Fuel_Type','Transmission'], as_index=False)['New_Price'].mean()

# %%
# Steps to create mean new price of cars with same name, year, fuel type and transmission
data=pd.merge(data,data_new_price,how='left',on=('Name','Year','Fuel_Type','Transmission'))

# %%
# Assign new price which are null
for i in range(len(data)):
    
    if ((data.loc[i, 'New_Price_x']!=data.loc[i, 'New_Price_x'])&(data.loc[i, 'New_Price_y']==data.loc[i, 'New_Price_y'])):
        data.loc[i, 'New_Price_x']=data.loc[i, 'New_Price_y']

# %%
# START OF UNIVARIATE ANALYSIS

# %%
# summary of data incl. 5 point summary of all numeric variables
data.describe()
# Out:
#              S.No.         Year  Kilometers_Driven      Mileage       Engine  \
# count  7253.000000  7253.000000       7.253000e+03  7251.000000  7207.000000
# mean   3626.000000  2013.365366       5.869906e+04    18.141580  1616.573470
# std    2093.905084     3.254421       8.442772e+04     4.562197   595.285137
# min       0.000000  1996.000000       1.710000e+02     0.000000    72.000000
# 25%    1813.000000  2011.000000       3.400000e+04    15.170000  1198.000000
# 50%    3626.000000  2014.000000       5.341600e+04    18.160000  1493.000000
# 75%    5439.000000  2016.000000       7.300000e+04    21.100000  1968.000000
# max    7252.000000  2019.000000       6.500000e+06    33.540000  5998.000000
#
#              Power        Seats  New_Price_x      Price_x      Price_y  \
# count  7078.000000  7200.000000  1114.000000  6698.000000  6698.000000
# mean    112.765214     5.279722    22.234031     9.402137     9.402137
# ...

# %%
data.groupby(['Location'], as_index=False)['Price_x'].mean()
# Out:
#       Location    Price_x
# 0    Ahmedabad   8.467700
# 1    Bangalore  13.416609
# 2      Chennai   7.621641
# 3   Coimbatore  14.796601
# 4        Delhi   9.696713
# 5    Hyderabad   9.720762
# 6       Jaipur   5.864895
# 7        Kochi  11.123791
# 8      Kolkata   5.599048
# 9       Mumbai   9.378336
# 10        Pune   6.701363

# %%
data.groupby(['Cont','Location'], as_index=False)['Price_x'].mean()
# Out:
#       Cont    Location    Price_x
# 0   Europe   Ahmedabad  15.768181
# 1   Europe   Bangalore  23.968980
# 2   Europe     Chennai  16.280293
# 3   Europe  Coimbatore  28.459724
# 4   Europe       Delhi  18.837990
# 5   Europe   Hyderabad  19.576876
# 6   Europe      Jaipur  10.397615
# 7   Europe       Kochi  22.020911
# 8   Europe     Kolkata  11.365261
# 9   Europe      Mumbai  16.629719
# 10  Europe        Pune  12.588729
# 11   India   Ahmedabad   5.023128
# 12   India   Bangalore   5.440851
# 13   India     Chennai   4.273328
# 14   India  Coimbatore   6.994410
# 15   India       Delhi   5.269641
# 16   India   Hyderabad   4.851409
# 17   India      Jaipur   4.180920
# 18   India       Kochi   6.417956
# 19   India     Kolkata   4.129353
# 20   India      Mumbai   5.005935
# 21   India        Pune   4.011823
# 22   Japan   Ahmedabad   7.977074
# 23   Japan   Bangalore   8.768736
# 24   Japan     Chennai   6.752731
# 25   Japan  Coimbatore  10.377543
# ...

# %%
# summary of data incl. 5 point summary of all variables
data.describe()
# Out:
#              S.No.         Year  Kilometers_Driven      Mileage       Engine  \
# count  7253.000000  7253.000000       7.253000e+03  7251.000000  7207.000000
# mean   3626.000000  2013.365366       5.869906e+04    18.141580  1616.573470
# std    2093.905084     3.254421       8.442772e+04     4.562197   595.285137
# min       0.000000  1996.000000       1.710000e+02     0.000000    72.000000
# 25%    1813.000000  2011.000000       3.400000e+04    15.170000  1198.000000
# 50%    3626.000000  2014.000000       5.341600e+04    18.160000  1493.000000
# 75%    5439.000000  2016.000000       7.300000e+04    21.100000  1968.000000
# max    7252.000000  2019.000000       6.500000e+06    33.540000  5998.000000
#
#              Power        Seats  New_Price_x      Price_x
# count  7078.000000  7200.000000  1114.000000  6698.000000
# mean    112.765214     5.279722    22.234031     9.402137
# std      53.493553     0.811660    26.883227    11.010331
# ...

# %%
# export describe outputs into excel
data.describe().to_excel('c4udesc.xls')

# %%
# function for combined boxplot and histplot
def histogram_boxplot(feature, figsize=(15,10), bins = None):
    """ Boxplot and histogram combined
    feature: 1-d feature array
    figsize: size of fig (default (9,8))
    bins: number of bins (default None / auto)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(nrows = 2, # Number of rows of the subplot grid= 2
                                           sharex = True, # x-axis will be shared among all subplots
                                           gridspec_kw = {"height_ratios": (.25, .75)}, 
                                           figsize = figsize 
                                           ) # creating the 2 subplots
    sns.boxplot(feature, ax=ax_box2, showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean value of the column
    sns.distplot(feature, kde=F, ax=ax_hist2, bins=bins,palette="winter") if bins else sns.distplot(feature, kde=False, ax=ax_hist2) # For histogram
    ax_hist2.axvline(np.mean(feature), color='green', linestyle='--') # Add mean to the histogram
    ax_hist2.axvline(np.median(feature), color='black', linestyle='-') # Add median to the histogram

# %%
# find central tendency and dispersions for numerical variables

# %%
histogram_boxplot(data["Year"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data[data['Year']<= 2003]

# %%
histogram_boxplot(data["Kilometers_Driven"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# min max scaler
from sklearn.preprocessing import MinMaxScaler

minmax_scale = MinMaxScaler()

minmax_scale
data['km_scle'] = minmax_scale.fit_transform(data[['Kilometers_Driven']])

# %%
histogram_boxplot(data["km_scle"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.preprocessing import FunctionTransformer   

log_transformer = FunctionTransformer(np.log1p)

log_transformer
data['Kilometers_Driven'].isnull().sum()   # Check number of null values
# data1['Distance']= data1['Distance'].fillna(data1['Distance'].mean())  # impute the null values using the mean
data['km_log'] = log_transformer.fit_transform(data[['Kilometers_Driven']])   # Log Transform the attribute

# %%
histogram_boxplot(data["km_log"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
histogram_boxplot(data["Mileage"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
histogram_boxplot(data["Engine"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
histogram_boxplot(data["Power"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
histogram_boxplot(data["Seats"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data[data['Seats']!=5].count()
# Out:
# S.No.                1206
# Name                 1206
# Location             1206
# Year                 1206
# Kilometers_Driven    1206
# Fuel_Type            1206
# Transmission         1206
# Owner_Type           1206
# Mileage              1206
# Engine               1160
# Power                1146
# Seats                1153
# New_Price_x           199
# Price_x              1094
# First_Name           1206
# Cont                 1206
# Price_y              1094
# New_Price_y           199
# km_log               1206
# dtype: int64

# %%
histogram_boxplot(data["New_Price_x"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
histogram_boxplot(data["Price_x"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# analyse categorical variable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 7252
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   float64
#  10  Power              7078 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  New_Price_x        1114 non-null   float64
#  13  Price_x            6698 non-null   float64
#  14  First_Name         7253 non-null   object
#  15  Cont               7253 non-null   object
# ...

# %%
plt.figure(figsize=(10,4)) # this creates a figure 8 inch wide, 4 inch high
sns.countplot(x="Location",order=data['Location'].value_counts().index,data=data)
plt.show()
# sns.countplot(data['Location']);

# %%
sns.countplot(data['Location']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Fuel_Type']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(25,10))
sns.countplot(data['First_Name']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Transmission']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Owner_Type']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Start of multivariate analysis

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, fmt=".2")
plt.show()

# %%
sns.scatterplot(data['Year'],data['Price_x']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(data['New_Price_x'],data['Price_x']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(data['Kilometers_Driven'],data['Price_x']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(data['Power'],data['Price_x']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(data['Engine'],data['Price_x']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(data['Mileage'],data['Price_x']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# data=data.drop(['km_log'], axis=1)
sns.pairplot(data,kind='reg');

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Location'],data['Price_x']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### plt.figure(figsize=(10,10))
# sns.boxplot(data['Location'],data['Price_x'],hue=data['Fuel_Type']);
# plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data['Location'],data['Price_x'],hue=data['Transmission']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data['Location'],data['Price_x'],hue=data['Owner_Type']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data['Location'],data['Price_x'],hue=data['Cont']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data[(data['Owner_Type']=='Third')&(data['Location']=='Delhi')]
# Out:
#       S.No.                        Name Location  Year  Kilometers_Driven  \
# 3876   3876       Honda Accord VTi-L AT    Delhi  2009              65462
# 4577   4577     BMW 5 Series 520d Sedan    Delhi  2012              72000
# 5781   5781  Lamborghini Gallardo Coupe    Delhi  2011               6500
# 6401   6401  Toyota Innova 2.5 GX 8 STR    Delhi  2011              53138
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats  \
# 3876    Petrol    Automatic      Third    11.10  2354.0  142.0    5.0
# 4577    Diesel    Automatic      Third    18.48     NaN    NaN    NaN
# 5781    Petrol    Automatic      Third     6.40  5204.0  560.0    2.0
# 6401    Diesel       Manual      Third    12.80  2494.0  102.0    8.0
#
#       New_Price_x  Price_x   First_Name    Cont     km_log
# 3876          NaN     3.50        Honda   Japan  11.089240
# 4577          NaN    13.85          BMW  Europe  11.184435
# 5781          NaN   120.00  Lamborghini  Europe   8.779711
# ...

# %%
plt.figure(figsize=(40,8))
sns.boxplot(data['First_Name'],data['Price_x']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 7252
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   float64
#  10  Power              7078 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  New_Price_x        1114 non-null   float64
#  13  Price_x            6698 non-null   float64
#  14  First_Name         7253 non-null   object
#  15  Cont               7253 non-null   object
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data['Cont'],data['Price_x']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(30,15))
sns.boxplot(data['Cont'],data['Price_x'],hue=data['Owner_Type']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(30,8))
sns.boxplot(data['Cont'],data['Price_x'],hue=data['Location']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# scatterplot(data['Year'],data['Price_x'],hue=data['children'])
sns.scatterplot(data['Year'],data['Price_x']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(data['Year'],data['Price_x'],hue=data['Cont']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,15))
sns.scatterplot(data['Year'],data['Price_x'],hue=data['Owner_Type']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['Location'],hue=data['Cont']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['Location'],hue=data['Fuel_Type']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['Location'],hue=data['Transmission']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['Location'],hue=data['Owner_Type']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data_ml=data.copy()
data_ml=data_ml.drop(['S.No.','Name','km_log'], axis=1)

# %%
# Lets treat outliers by flooring and capping
def treat_outliers(df,col):
    '''
    treats outliers in a varaible
    col: str, name of the numerical varaible
    df: data frame
    col: name of the column
    '''
    Q1=df[col].quantile(0.25) # 25th quantile
    Q3=df[col].quantile(0.75)  # 75th quantile
    IQR=Q3-Q1
    Lower_Whisker = Q1 - 1.5*IQR 
    Upper_Whisker = Q3 + 1.5*IQR
    df[col] = np.clip(df[col], Lower_Whisker, Upper_Whisker) # all the values samller than Lower_Whisker will be assigned value of Lower_whisker 
                                                            # and all the values above upper_whishker will be assigned value of upper_Whisker 
    return df
# col_list=['Year','Kilometers_Driven','Mileage','Power','Price_x','New_Price_x']
col_list=['Year','Kilometers_Driven','Mileage','Power','Engine','Price_x','New_Price_x']
# col_list=['Year','Kilometers_Driven','Mileage','Engine']
# col_list=['Year','Kilometers_Driven','Mileage','Engine','New_Price']
for c in col_list:
    data_ml= treat_outliers(data_ml,c)

# %%
data_ml['Engine'].fillna(data_ml['Engine'].median(), inplace=True)  # mean imputation
data_ml['Power'].fillna(data_ml['Power'].median(), inplace=True)  # mean imputation
data_ml['Mileage'].fillna(data_ml['Mileage'].median(), inplace=True)  # mean imputation
data_ml['New_Price_x'].fillna(data_ml['New_Price_x'].median(), inplace=True)  # mean imputation
data_ml=data_ml[data_ml['Price_x'].notna()]

# %%
# create model without engine (as linearly related to power), seats (as mostly 5),continent and first name
data_ml=data_ml.drop(['Engine','Seats','Cont','First_Name'], axis=1)
data_ml= pd.get_dummies(data_ml,columns=['Location','Fuel_Type','Transmission','Owner_Type'])
data_ml=data_ml.drop(['Location_Pune','Fuel_Type_Diesel','Transmission_Automatic','Owner_Type_First'], axis=1)

# %%
# independant variables
X = data_ml.drop(['Price_x'], axis=1)
# X = data_ml.drop(['Price_x','Cont_Europe','Cont_India','Cont_Japan','Cont_Korea'], axis=1)
# X = data_ml.drop(['Price_x','New_Price_x'], axis=1)
# the dependent variable
y = data_ml[['Price_x']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.84260593392004

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.8449273879933641

# %%
# let's add some additional variable

# %%
data_ml=data.copy()
data_ml=data_ml.drop(['S.No.','Name','km_log'], axis=1)

# %%
# Lets treat outliers by flooring and capping
def treat_outliers(df,col):
    '''
    treats outliers in a varaible
    col: str, name of the numerical varaible
    df: data frame
    col: name of the column
    '''
    Q1=df[col].quantile(0.25) # 25th quantile
    Q3=df[col].quantile(0.75)  # 75th quantile
    IQR=Q3-Q1
    Lower_Whisker = Q1 - 1.5*IQR 
    Upper_Whisker = Q3 + 1.5*IQR
    df[col] = np.clip(df[col], Lower_Whisker, Upper_Whisker) # all the values samller than Lower_Whisker will be assigned value of Lower_whisker 
                                                            # and all the values above upper_whishker will be assigned value of upper_Whisker 
    return df
# col_list=['Year','Kilometers_Driven','Mileage','Power','Price_x','New_Price_x']
col_list=['Year','Kilometers_Driven','Mileage','Power','Engine','Price_x','New_Price_x']
# col_list=['Year','Kilometers_Driven','Mileage','Engine']
# col_list=['Year','Kilometers_Driven','Mileage','Engine','New_Price']
for c in col_list:
    data_ml= treat_outliers(data_ml,c)

# %%
data_ml['Engine'].fillna(data_ml['Engine'].median(), inplace=True)  # mean imputation
data_ml['Power'].fillna(data_ml['Power'].median(), inplace=True)  # mean imputation
data_ml['Mileage'].fillna(data_ml['Mileage'].median(), inplace=True)  # mean imputation
data_ml['New_Price_x'].fillna(data_ml['New_Price_x'].median(), inplace=True)  # mean imputation
data_ml=data_ml[data_ml['Price_x'].notna()]

# %%
# Let's add 'First_Name'
data_ml=data_ml.drop(['Engine','Seats','Cont'], axis=1)
data_ml= pd.get_dummies(data_ml,columns=['Location','Fuel_Type','Transmission','First_Name','Owner_Type'])
data_ml=data_ml.drop(['Location_Pune','Fuel_Type_Diesel','Transmission_Automatic','Owner_Type_First','First_Name_Maruti'], axis=1)

# %%
# independant variables
X = data_ml.drop(['Price_x'], axis=1)

y = data_ml[['Price_x']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.8965530717339955

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.900021171789219

# %%
# Adding first_name improved..let's add some additional variable

# %%
data_ml=data.copy()
data_ml=data_ml.drop(['S.No.','Name','km_log'], axis=1)

# %%
# Lets treat outliers by flooring and capping
def treat_outliers(df,col):
    '''
    treats outliers in a varaible
    col: str, name of the numerical varaible
    df: data frame
    col: name of the column
    '''
    Q1=df[col].quantile(0.25) # 25th quantile
    Q3=df[col].quantile(0.75)  # 75th quantile
    IQR=Q3-Q1
    Lower_Whisker = Q1 - 1.5*IQR 
    Upper_Whisker = Q3 + 1.5*IQR
    df[col] = np.clip(df[col], Lower_Whisker, Upper_Whisker) # all the values samller than Lower_Whisker will be assigned value of Lower_whisker 
                                                            # and all the values above upper_whishker will be assigned value of upper_Whisker 
    return df
# col_list=['Year','Kilometers_Driven','Mileage','Power','Price_x','New_Price_x']
col_list=['Year','Kilometers_Driven','Mileage','Power','Engine','Price_x','New_Price_x']
# col_list=['Year','Kilometers_Driven','Mileage','Engine']
# col_list=['Year','Kilometers_Driven','Mileage','Engine','New_Price']
for c in col_list:
    data_ml= treat_outliers(data_ml,c)

# %%
data_ml['Engine'].fillna(data_ml['Engine'].median(), inplace=True)  # mean imputation
data_ml['Power'].fillna(data_ml['Power'].median(), inplace=True)  # mean imputation
data_ml['Mileage'].fillna(data_ml['Mileage'].median(), inplace=True)  # mean imputation
data_ml['New_Price_x'].fillna(data_ml['New_Price_x'].median(), inplace=True)  # mean imputation
data_ml=data_ml[data_ml['Price_x'].notna()]

# %%
# Let's add cont
data_ml=data_ml.drop(['Engine','Seats'], axis=1)
data_ml= pd.get_dummies(data_ml,columns=['Location','Fuel_Type','Transmission','First_Name','Owner_Type','Cont'])
data_ml=data_ml.drop(['Location_Pune','Fuel_Type_Diesel','Transmission_Automatic','Owner_Type_First','First_Name_Maruti','Cont_Europe'], axis=1)

# %%
# independant variables
X = data_ml.drop(['Price_x'], axis=1)

y = data_ml[['Price_x']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.8965530717339952

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.9005082164380608

# %%
# R2 didn't improve..so let's drop cont..and replace power with engine

# %%
data_ml=data.copy()
data_ml=data_ml.drop(['S.No.','Name','km_log'], axis=1)

# %%
# Lets treat outliers by flooring and capping
def treat_outliers(df,col):
    '''
    treats outliers in a varaible
    col: str, name of the numerical varaible
    df: data frame
    col: name of the column
    '''
    Q1=df[col].quantile(0.25) # 25th quantile
    Q3=df[col].quantile(0.75)  # 75th quantile
    IQR=Q3-Q1
    Lower_Whisker = Q1 - 1.5*IQR 
    Upper_Whisker = Q3 + 1.5*IQR
    df[col] = np.clip(df[col], Lower_Whisker, Upper_Whisker) # all the values samller than Lower_Whisker will be assigned value of Lower_whisker 
                                                            # and all the values above upper_whishker will be assigned value of upper_Whisker 
    return df
# col_list=['Year','Kilometers_Driven','Mileage','Power','Price_x','New_Price_x']
col_list=['Year','Kilometers_Driven','Mileage','Power','Engine','Price_x','New_Price_x']
# col_list=['Year','Kilometers_Driven','Mileage','Engine']
# col_list=['Year','Kilometers_Driven','Mileage','Engine','New_Price']
for c in col_list:
    data_ml= treat_outliers(data_ml,c)

# %%
data_ml['Engine'].fillna(data_ml['Engine'].median(), inplace=True)  # mean imputation
data_ml['Power'].fillna(data_ml['Power'].median(), inplace=True)  # mean imputation
data_ml['Mileage'].fillna(data_ml['Mileage'].median(), inplace=True)  # mean imputation
data_ml['New_Price_x'].fillna(data_ml['New_Price_x'].median(), inplace=True)  # mean imputation
data_ml=data_ml[data_ml['Price_x'].notna()]

# %%
# Let's replace power with engine
data_ml=data_ml.drop(['Power','Seats','Cont'], axis=1)
data_ml= pd.get_dummies(data_ml,columns=['Location','Fuel_Type','Transmission','First_Name','Owner_Type'])
data_ml=data_ml.drop(['Location_Pune','Fuel_Type_Diesel','Transmission_Automatic','Owner_Type_First','First_Name_Maruti'], axis=1)

# %%
# independant variables
X = data_ml.drop(['Price_x'], axis=1)

y = data_ml[['Price_x']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.8859888440870572

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.8916935456634241

# %%
R2 dropped..so let's see impact of dropping kilometres driven

# %%
data_ml=data.copy()
data_ml=data_ml.drop(['S.No.','Name'], axis=1)

# %%
# Lets treat outliers by flooring and capping
def treat_outliers(df,col):
    '''
    treats outliers in a varaible
    col: str, name of the numerical varaible
    df: data frame
    col: name of the column
    '''
    Q1=df[col].quantile(0.25) # 25th quantile
    Q3=df[col].quantile(0.75)  # 75th quantile
    IQR=Q3-Q1
    Lower_Whisker = Q1 - 1.5*IQR 
    Upper_Whisker = Q3 + 1.5*IQR
    df[col] = np.clip(df[col], Lower_Whisker, Upper_Whisker) # all the values samller than Lower_Whisker will be assigned value of Lower_whisker 
                                                            # and all the values above upper_whishker will be assigned value of upper_Whisker 
    return df
# col_list=['Year','Kilometers_Driven','Mileage','Power','Price_x','New_Price_x']
col_list=['Year','Kilometers_Driven','Mileage','Power','Engine','Price_x','New_Price_x']
# col_list=['Year','Kilometers_Driven','Mileage','Engine']
# col_list=['Year','Kilometers_Driven','Mileage','Engine','New_Price']
for c in col_list:
    data_ml= treat_outliers(data_ml,c)

# %%
data_ml['Engine'].fillna(data_ml['Engine'].median(), inplace=True)  # mean imputation
data_ml['Power'].fillna(data_ml['Power'].median(), inplace=True)  # mean imputation
data_ml['Mileage'].fillna(data_ml['Mileage'].median(), inplace=True)  # mean imputation
data_ml['New_Price_x'].fillna(data_ml['New_Price_x'].median(), inplace=True)  # mean imputation
data_ml=data_ml[data_ml['Price_x'].notna()]

# %%
# Let's drop km driven
data_ml=data_ml.drop(['Engine','Seats','Cont','Kilometers_Driven'], axis=1)
data_ml= pd.get_dummies(data_ml,columns=['Location','Fuel_Type','Transmission','First_Name','Owner_Type'])
data_ml=data_ml.drop(['Location_Pune','Fuel_Type_Diesel','Transmission_Automatic','Owner_Type_First','First_Name_Maruti'], axis=1)

# %%
# independant variables
X = data_ml.drop(['Price_x'], axis=1)

y = data_ml[['Price_x']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.8940209591761306

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.8982014175364526

# %%
R2 dropped..so let's replace engine with power

# %%
data_ml=data.copy()
data_ml=data_ml.drop(['S.No.','Name'], axis=1)

# %%
# Lets treat outliers by flooring and capping
def treat_outliers(df,col):
    '''
    treats outliers in a varaible
    col: str, name of the numerical varaible
    df: data frame
    col: name of the column
    '''
    Q1=df[col].quantile(0.25) # 25th quantile
    Q3=df[col].quantile(0.75)  # 75th quantile
    IQR=Q3-Q1
    Lower_Whisker = Q1 - 1.5*IQR 
    Upper_Whisker = Q3 + 1.5*IQR
    df[col] = np.clip(df[col], Lower_Whisker, Upper_Whisker) # all the values samller than Lower_Whisker will be assigned value of Lower_whisker 
                                                            # and all the values above upper_whishker will be assigned value of upper_Whisker 
    return df
# col_list=['Year','Kilometers_Driven','Mileage','Power','Price_x','New_Price_x']
col_list=['Year','Kilometers_Driven','Mileage','Power','Engine','Price_x','New_Price_x']
# col_list=['Year','Kilometers_Driven','Mileage','Engine']
# col_list=['Year','Kilometers_Driven','Mileage','Engine','New_Price']
for c in col_list:
    data_ml= treat_outliers(data_ml,c)

# %%
data_ml['Engine'].fillna(data_ml['Engine'].median(), inplace=True)  # mean imputation
data_ml['Power'].fillna(data_ml['Power'].median(), inplace=True)  # mean imputation
data_ml['Mileage'].fillna(data_ml['Mileage'].median(), inplace=True)  # mean imputation
data_ml['New_Price_x'].fillna(data_ml['New_Price_x'].median(), inplace=True)  # mean imputation
data_ml=data_ml[data_ml['Price_x'].notna()]

# %%
# Let's add back power
data_ml=data_ml.drop(['Engine','Seats','Cont'], axis=1)
data_ml= pd.get_dummies(data_ml,columns=['Location','Fuel_Type','Transmission','First_Name','Owner_Type'])
data_ml=data_ml.drop(['Location_Pune','Fuel_Type_Diesel','Transmission_Automatic','Owner_Type_First','First_Name_Maruti'], axis=1)

# %%
# independant variables
X = data_ml.drop(['Price_x'], axis=1)

y = data_ml[['Price_x']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.8965530717339955

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.900021171789219

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print("The Root Mean Square Error (RMSE) of the model is for training set is",np.sqrt(mean_squared_error(y_train,regression_model.predict(X_train))))
# Out:
# The Root Mean Square Error (RMSE) of the model is for training set is 1.829360845379622

# %%
print("The Root Mean Square Error (RMSE) of the model is for testing set is",np.sqrt(mean_squared_error(y_test,regression_model.predict(X_test))))
# Out:
# The Root Mean Square Error (RMSE) of the model is for testing set is 1.8270446651753358

# %%
mean_absolute_error(y_train, regression_model.predict(X_train))
# Out:
# 1.3382107833411971

# %%
mean_absolute_error(y_test,regression_model.predict(X_test))
# Out:
# 1.3475545400920175

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
X_train1, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

olsmod0 = sm.OLS(y_train, X_train1)
olsres0 = olsmod0.fit()
print(olsres0.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Price_x   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     787.8
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):               0.00
# Time:                        16:36:09   Log-Likelihood:                -9483.4
# No. Observations:                4688   AIC:                         1.907e+04
# Df Residuals:                    4636   BIC:                         1.941e+04
# Df Model:                          51
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -1157.9368     25.226    -45.902      0.000   -1207.392   -1108.481
# ...

# %%
# VIF and MULTICOLLINEARITY
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_series1 = pd.Series([variance_inflation_factor(X.values,i) for i in range(X.shape[1])],index=X.columns)
print('Series before feature selection: \n\n{}\n'.format(vif_series1))
# Out:
# Series before feature selection:
#
# const                        871378.794570
# Year                              2.162783
# Kilometers_Driven                 1.920605
# Mileage                           2.943062
# Power                             4.756220
# New_Price_x                       1.268771
# Location_Ahmedabad                1.338612
# Location_Bangalore                1.533997
# Location_Chennai                  1.668891
# Location_Coimbatore               1.956586
# Location_Delhi                    1.783431
# Location_Hyderabad                1.986689
# Location_Jaipur                   1.578564
# Location_Kochi                    1.962618
# Location_Kolkata                  1.853383
# Location_Mumbai                   2.085344
# Fuel_Type_CNG                     1.061407
# Fuel_Type_Electric                1.010345
# Fuel_Type_LPG                     1.016354
# Fuel_Type_Petrol                  2.161488
# Transmission_Manual               2.335483
# ...

# %%
olsmod1 = sm.OLS(y_train, X_train1)
olsres1 = olsmod1.fit()
print(olsres1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Price_x   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     787.8
# Date:                Tue, 20 Apr 2021   Prob (F-statistic):               0.00
# Time:                        22:55:28   Log-Likelihood:                -9483.4
# No. Observations:                4688   AIC:                         1.907e+04
# Df Residuals:                    4636   BIC:                         1.941e+04
# Df Model:                          51
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                     -1157.9368     25.226    -45.902      0.000   -1207.392   -1108.481
# ...

# %%
residual= olsres1.resid
np.mean(residual)
# Out:
# 2.2299184114699016e-11

# %%
residual=olsres1.resid
fitted=olsres1.fittedvalues #predicted values

# %%
sns.set_style("whitegrid")
sns.residplot(fitted,residual,color="purple",lowess=True)
plt.xlabel("Fitted Values")
plt.ylabel("Residual")
plt.title("Residual PLOT")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(residual)
plt.title('Normality of residuals')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip

name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(residual, X_train1)
lzip(name, test)
# Out:
# [('F statistic', 1.0299939844593322), ('p-value', 0.2395592346699847)]

# %%
regression_model.coef_
# Out:
# array([[ 5.79008130e-01, -1.32296769e-05, -1.77343372e-01,
#          4.25884086e-02,  1.70962920e-02,  1.38593172e-01,
#          8.40218740e-01,  2.12879775e-01,  6.16662839e-01,
#         -3.96231574e-01,  7.29554201e-01,  2.30725341e-01,
#         -1.21914544e-01, -1.04140805e+00, -1.61157965e-01,
#         -1.09337606e+00,  4.41567688e+00, -1.65614726e+00,
#         -2.05412006e+00, -1.10701267e+00,  2.05244411e+00,
#          5.16095220e+00,  4.19021867e+00,  9.32296098e+00,
#         -1.45682333e+00, -2.04993439e+00, -1.72920901e+00,
#          3.58139462e-01, -3.52237656e-01, -4.96635654e-01,
#         -2.58875914e-01, -1.82454640e-01,  3.44169138e-15,
#          5.10418410e+00,  4.55558356e+00,  8.88178420e-16,
#          5.64501231e+00, -6.74249265e-01,  4.27729930e+00,
#          8.39706761e+00,  1.75811627e+00, -8.82979116e-01,
#          4.13776862e+00, -8.28223352e-01, -1.23383854e-01,
#         -3.10042446e+00, -1.89683496e+00,  2.54481776e+00,
# ...

# %%
a = regression_model.coef_
coeff_data = pd.DataFrame()
coeff_data['Coefs'] = regression_model.coef_[0]
coeff_data['Feature'] = X_train.columns
coeff_data = coeff_data.append({'Coefs': regression_model.intercept_, 'Feature': "Intercept"}, ignore_index = True)
coeff_data.to_csv('c4u1.csv')
