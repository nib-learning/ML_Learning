# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline

# %%
# read the csv file
data=pd.read_csv('CardioGoodFitness.csv')

# %%
# check the head of data set
data.head(5)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
# check the tail of data set
data.tail(5)
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
# check the shape
data.shape
# Out:
# (180, 9)

# %%
# check the info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
# find if there is any null values
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# START OF UNIVARIATE ANALYSIS

# %%
# summary of data incl. 5 point summary of all numeric variables
data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
# summary of data incl. 5 point summary of all variables
data.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
# export describe outputs into excel
data.describe().to_excel('cardiodescribe.xls')

# %%
#find distribution of age
sns.boxplot(data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
# find distribution
sns.distplot(data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
# find number of customers above 40
data[data['Age']>40].count()
# Out:
# Product          12
# Age              12
# Gender           12
# Education        12
# MaritalStatus    12
# Usage            12
# Fitness          12
# Income           12
# Miles            12
# dtype: int64

# %%
# find upper whisker
data['Age'].quantile(0.75)+(1.5*(data['Age'].quantile(0.75)-data['Age'].quantile(0.25)))
# Out:
# 46.5

# %%
# find IQR
data['Age'].quantile(0.75)-data['Age'].quantile(0.25)
# Out:
# 9.0

# %%
# find mode
data['Age'].mode()
# Out:
# 0    25
# dtype: int64

# %%
# Age analysis
# Median Age of customers buying treadmill/50% of customers less than 26 years with 75% of cutomers below 33 years and 75% of customers above 24.
# right skewed data. 25 year old (mode) buys the treadmill the most.
#Spread is high.Age is right skewed with IQR as 9 years and std. deviation of 6.9 years. Range is 32 years
# there are three outlier values above upper whisker of 46.5 with a max age of 50 years

# %%
# visualise distribution
sns.boxplot(data['Education'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education'>

# %%
# visualise distribution
sns.distplot(data['Education'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Education', ylabel='Density'>

# %%
# find IQR
data['Education'].quantile(0.75)-data['Education'].quantile(0.25)
# Out:
# 2.0

# %%
# find mode
data['Education'].mode()
# Out:
# 0    16
# dtype: int64

# %%
# Education analysis
#Customers median and mode education is 16years with 75% of cutomers below 16 years and 75% of customers above 14 years.
# no notable skewing (mean and median very close)
#IQR is 2 years and std. deviation of 1.6 years. Range is 9 years. 
# there are two outlier values above upper whisker of 18 years with a max education of 21 years

# %%
# visualise distribution
sns.boxplot(data['Usage'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Usage'>

# %%
# visualise distribution
sns.distplot(data['Usage']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# find IQR
data['Usage'].quantile(0.75)-data['Usage'].quantile(0.25)
# Out:
# 1.0

# %%
# 50% of the people plans to use 3 times a week and 75% less than 4 times a week. Mean is 3.45
# data is rigth skewed. Std deviation and IQR of 1, spread low but range of 5.
# two outliers using 6 and 7 times a day

# %%
sns.boxplot(data['Fitness'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fitness'>

# %%
sns.distplot(data['Fitness']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# find IQR
data['Fitness'].quantile(0.75)-data['Fitness'].quantile(0.25)
# Out:
# 1.0

# %%
# 50% of the people rates themselves to be less than 3 for fitnss  and 75% less than 4 and 75% above 3. Mean is 3.3
# slightly right skewed. Std. dev and IQR are circa. 1. 
# one outlier with rating of 1

# %%
# find number of customer below fitness rating of 3
data[data['Fitness']<3].count()
# Out:
# Product          28
# Age              28
# Gender           28
# Education        28
# MaritalStatus    28
# Usage            28
# Fitness          28
# Income           28
# Miles            28
# dtype: int64

# %%
# find number of customers above fitness rating of 4
data[data['Fitness']>4].count()
# Out:
# Product          31
# Age              31
# Gender           31
# Education        31
# MaritalStatus    31
# Usage            31
# Fitness          31
# Income           31
# Miles            31
# dtype: int64

# %%
sns.boxplot(data['Income'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income'>

# %%
sns.distplot(data['Income']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# find IQR
data['Income'].quantile(0.75)-data['Income'].quantile(0.25)
# Out:
# 14609.25

# %%
data['Income'].mode()
# Out:
# 0    45480
# dtype: int64

# %%
# 50% of the people has income less than 50k and 75% below $58k and 75% above 44k. Mean is $53,719
# 10 outlier with income above $80k. IQR is $14,609 and std. dev is $16,506. Range is $75k.
# rights skewed data

# %%
# find number of customers with income more than 90k
data[data['Income']>90000].count()
# Out:
# Product          12
# Age              12
# Gender           12
# Education        12
# MaritalStatus    12
# Usage            12
# Fitness          12
# Income           12
# Miles            12
# dtype: int64

# %%
sns.boxplot(data['Miles'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Miles'>

# %%
sns.distplot(data['Miles']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# find IQR
data['Miles'].quantile(0.75)-data['Miles'].quantile(0.25)
# Out:
# 48.75

# %%
data['Miles'].mode()
# Out:
# 0    85
# dtype: int64

# %%
# 50% of the has expected miles less than 94 miles and 75% less than 114 miles and more than 75% above 66 miles
# 8 outlier with miles more than 180 miles
# IQR of 48.75. Range is 339 miles. high spread
# right skewed

# %%
# visualise distribution betwee single and married
sns.countplot(data['MaritalStatus']);
# more married individuals buy than single
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# visualise distribution betwee males and females
sns.countplot(data['Gender']);
# more men buy than females
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# visualise distribution betwee males and females split by marital status
sns.countplot(data['Gender'],hue=data['MaritalStatus']);
# Men and females who are married buy than the singles
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# visualisation of products and their count
sns.countplot(data['Product']);
# TM195 is most popular followed by TM498 and TM798
# sales of TM798 is only half of TM195 and 2/3rd of TM498.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Start of multivariate analysis

# %%
sns.heatmap(data.corr(),annot=True);
# Age is not highly corelated to any other variable
# as percieved fitness of customer increases, the expected usage and miles goes up
# miles goes up as usage goes up
# income goes up when education goes up...not high correlation

# %%
# visualise relationship between variable
sns.pairplot(data,kind='reg');

# %%
sns.lmplot(y='Fitness',x='Usage',data=data);

# %%
sns.lmplot(y='Fitness',x='Miles',data=data);

# %%
sns.lmplot(y='Usage',x='Miles',data=data);

# %%
sns.lmplot(y='Income',x='Education',data=data);

# %%
sns.countplot(data['Gender'],hue=data['MaritalStatus']);
# more married people use treadmill than single
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average age of customers for products separately
sns.boxplot(data['Product'],data['Age']);
# TM798 used moistly by 25-30 years. Other products used by many 30+ also.
# TM195 used by slighly younger peope (less than 25 also)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average customer income for products separately
sns.boxplot(data['Product'],data['Income']);
# TM798 used by higher income (>60k)..other by <55k
# TM198 used by lower income
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average customer income for products separately separated by gender
sns.boxplot(data['Product'],data['Age'],hue=data['Gender']);
# TM498 used by  older fmales than males
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average customer income for products separately separated by marital status
sns.boxplot(data['Product'],data['Age'],hue=data['MaritalStatus']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average expected miles for products separately 
sns.boxplot(data['Product'],data['Miles']);
# TM798 users ecpxted to do 100 miles+-hgiher miles compared with lower miles for other twop
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average expected miles for products separately separated by gender
sns.boxplot(data['Product'],data['Miles'],hue=data['Gender']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average expected miles for products separately separated by marital status
sns.boxplot(data['Product'],data['Miles'],hue=data['MaritalStatus']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average expected usage for products separately
sns.boxplot(data['Product'],data['Usage']);
Lowest usage on TM498...higher usage for TM798 with TM195 in the middle
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average expected usage for products separately separated by gender
sns.boxplot(data['Product'],data['Usage'],hue=data['Gender']);
female users expect to use more for TM498 and TM798..but for TM195, males expected to use more
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average expected usage for products separately separated by marital status
sns.boxplot(data['Product'],data['Usage'],hue=data['MaritalStatus']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average fitness for products separately
sns.boxplot(data['Product'],data['Fitness']);
# fitter people use TM798 and might be because used by younger people
# other two products used by avergae fit
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average fitness for products separately separated by gender
sns.boxplot(data['Product'],data['Fitness'],hue=data['Gender']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average fitness for products separately separated by marital status
sns.boxplot(data['Product'],data['Fitness'],hue=data['MaritalStatus']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average income for products separately separated by gender
sns.boxplot(data['Product'],data['Income'],hue=data['Gender']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average income for products separately separated by marital status
sns.boxplot(data['Product'],data['Income'],hue=data['MaritalStatus']);
higher income users of TM798 are married
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average education for products separately
sns.boxplot(data['Product'],data['Education']);
most educated use TM798 which might be the reflection of higher income
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average education for products separately separated by gender
sns.boxplot(data['Product'],data['Education'],hue=data['Gender']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find average education for products separately separated by marital status
sns.boxplot(data['Product'],data['Education'],hue=data['MaritalStatus']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot(data['Product'],data['Education']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data['Product'],data['Usage'],hue=data['Gender']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data['Product'],data['Fitness'],hue=data['Gender']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.catplot(x='Product',y='Age',col='Gender',row='MaritalStatus',data=data);
# single and married males prefer TM798 than women.

# %%
sns.catplot(x='Product',y='Usage',col='Gender',row='MaritalStatus',data=data);

# %%
sns.catplot(x='Product',y='Income',col='Gender',row='MaritalStatus',data=data);

# %%
sns.catplot(x='Product',y='Fitness',col='Gender',row='MaritalStatus',data=data);

# %%
sns.swarmplot(x='Product',y='Income',hue='MaritalStatus',data=data);

# %%
sns.swarmplot(x='Product',y='Income',hue='Gender',data=data);

# %%
sns.swarmplot(x='Product',y='Usage',hue='MaritalStatus',data=data);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# find  female customer count for users of TM798
data[(data['Gender']=='Female') &(data['Product']=='TM798') ].count()
# Out:
# Product          7
# Age              7
# Gender           7
# Education        7
# MaritalStatus    7
# Usage            7
# Fitness          7
# Income           7
# Miles            7
# dtype: int64

# %%
# find  customer count for users of TM798
data[data['Product']=='TM798'].count()
# Out:
# Product          40
# Age              40
# Gender           40
# Education        40
# MaritalStatus    40
# Usage            40
# Fitness          40
# Income           40
# Miles            40
# dtype: int64

# %%
sns.catplot(x='Product',y='Fitness',col='Gender',row='MaritalStatus',data=data);
# single females feel less fir that single men

# %%
# sns.countplot(data['MaritalStatus'],hue=data['Product']);
sns.countplot(data['Product'],hue=data['MaritalStatus']);
# every product is used more by married individuals
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pointplot(x='Gender',y='Fitness',data=data,hue='MaritalStatus');
# fitness of married female more than single female
# fitness of married men less than single men

# %%
# sns.countplot(data['Gender'],hue=data['Product']);
sns.countplot(data['Product'],hue=data['Gender']);
# 195 and 498 bought almost equally by men and women, but TM798 mostly bought by men
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# sns.countplot(data['MaritalStatus'],hue=data['Product']);
sns.countplot(data['Product'],hue=data['MaritalStatus']);
# TM498 and Tm195 bought 50% higher by married pople than singles excpet for TM798 where it is almost the same
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot(data['Product'],data['Gender'],hue=data['MaritalStatus']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.swarmplot(data['Product'],data['Age']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot(data['Product'],data['Income']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot(data['Product'],data['Gender']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.swarmplot(data['Product'],data['MaritalStatus']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...
