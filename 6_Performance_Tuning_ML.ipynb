# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline

# %%
# read the csv file
data=pd.read_csv('BankChurners.csv')

# %%
# check the head of data set
data.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
# check the tail of data set
data.tail(5)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
# check the shape
data.shape
# Out:
# (10127, 21)

# %%
# check the info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
# find if there is any null values
data.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
data['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
# cols_cat= data.select_dtypes(['category'])
cols_cat= data.select_dtypes(['object'])

# %%
# find unique values
for i in cols_cat.columns:
    print('Unique values in',i, 'are :')
    print(cols_cat[i].value_counts())
    print('*'*50)
# Out:
# Unique values in Attrition_Flag are :
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64
# **************************************************
# Unique values in Gender are :
# F    5358
# M    4769
# Name: Gender, dtype: int64
# **************************************************
# Unique values in Education_Level are :
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64
# **************************************************
# Unique values in Marital_Status are :
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64
# **************************************************
# Unique values in Income_Category are :
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# ...

# %%
# START OF UNIVARIATE ANALYSIS

# %%
# summary of data incl. 5 point summary of all numeric variables
data.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
# export describe outputs into excel
data.describe().to_excel('bankchurn.xls')
# Out:
# <ipython-input-20-88c2fb4b4622>:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   data.describe().to_excel('bankchurn.xls')

# %%
# function for combined boxplot and histplot
def histogram_boxplot(feature, figsize=(15,10), bins = None):
    """ Boxplot and histogram combined
    feature: 1-d feature array
    figsize: size of fig (default (9,8))
    bins: number of bins (default None / auto)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(nrows = 2, # Number of rows of the subplot grid= 2
                                           sharex = True, # x-axis will be shared among all subplots
                                           gridspec_kw = {"height_ratios": (.25, .75)}, 
                                           figsize = figsize 
                                           ) # creating the 2 subplots
    sns.boxplot(feature, ax=ax_box2, showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean value of the column
    sns.distplot(feature, kde=F, ax=ax_hist2, bins=bins,palette="winter") if bins else sns.distplot(feature, kde=False, ax=ax_hist2) # For histogram
    ax_hist2.axvline(np.mean(feature), color='green', linestyle='--') # Add mean to the histogram
    ax_hist2.axvline(np.median(feature), color='black', linestyle='-') # Add median to the histogram

# %%
# find central tendency and dispersions for numerical variables

# %%
histogram_boxplot(data["Customer_Age"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Dependent_count"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Months_on_book"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Total_Relationship_Count"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Months_Inactive_12_mon"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Contacts_Count_12_mon"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Credit_Limit"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Total_Revolving_Bal"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Avg_Open_To_Buy"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data [data['Credit_Limit']>30000]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 6      810347208  Existing Customer            51      M                4
# 16     709967358  Existing Customer            48      M                4
# 40     827111283  Existing Customer            45      M                3
# 45     712661433  Existing Customer            49      M                4
# 61     712030833  Attrited Customer            48      M                2
# ...          ...                ...           ...    ...              ...
# 10088  709188108  Existing Customer            45      M                2
# 10095  789023508  Existing Customer            46      M                3
# 10098  716644008  Attrited Customer            55      M                3
# 10110  718225683  Existing Customer            56      M                1
# 10112  708564858  Attrited Customer            33      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
histogram_boxplot(data["Total_Amt_Chng_Q4_Q1"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Total_Trans_Amt"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Total_Trans_Ct"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Total_Ct_Chng_Q4_Q1"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
histogram_boxplot(data["Avg_Utilization_Ratio"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book      ...        Credit_Limit  Total_Revolving_Bal  \
# 0              39      ...             12691.0                  777
# ...

# %%
data['Avg_Trans_Amt_Chng_Q4_Q1']=data['Total_Amt_Chng_Q4_Q1']/data['Total_Ct_Chng_Q4_Q1']

# %%
data['Avg_Trans_Amt']=data['Total_Trans_Amt']/data['Total_Trans_Ct']

# %%
histogram_boxplot(data["Avg_Trans_Amt_Chng_Q4_Q1"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-32-2de303da7851> in <module>()
# ----> 1 histogram_boxplot(data["Avg_Trans_Amt_Chng_Q4_Q1"])
#
# <ipython-input-12-1150088ee031> in histogram_boxplot(feature, figsize, bins)
#      12                                            ) # creating the 2 subplots
# ...

# %%
histogram_boxplot(data["Avg_Trans_Amt"])
# Out:
# C:\Users\meeranibu\.conda\envs\tfdeeplearning\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# analyse categorical variable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   category
#  4   CityTier                  4888 non-null   category
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   category
#  7   Gender                    4888 non-null   category
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   category
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   category
# ...

# %%
sns.countplot(data['Attrition_Flag']);

# %%
plt.figure(figsize=(5,2))
sns.countplot(data['Gender']);
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['Education_Level']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Marital_Status']);

# %%
plt.figure(figsize=(10,8))
sns.countplot(data['Income_Category']);
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(data['Card_Category']);

# %%
data['Card_Category'].value_counts()
# Out:
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %%
data['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
# change target variable to 1 and 0

# %%
data['attrition'] = data['Attrition_Flag'].replace({'Attrited Customer':1, 'Existing Customer':0})

# %%
data['attrition'].value_counts()
# Out:
# 2    8500
# 1    1627
# Name: attrition, dtype: int64

# %%
data['attrition'].astype(int)
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
# 5        2
# 6        2
# 7        2
# 8        2
# 9        2
# 10       2
# 11       2
# 12       2
# 13       2
# 14       2
# 15       2
# 16       2
# 17       2
# 18       2
# 19       2
# 20       2
# 21       1
# 22       2
# 23       2
# 24       2
# 25       2
# 26       2
# 27       2
# 28       2
# 29       2
#         ..
# 10097    2
# 10098    1
# 10099    2
# 10100    2
# 10101    2
# 10102    2
# 10103    1
# 10104    2
# 10105    1
# 10106    2
# 10107    1
# 10108    1
# 10109    2
# 10110    2
# 10111    2
# 10112    1
# 10113    1
# 10114    2
# 10115    2
# 10116    2
# 10117    2
# 10118    1
# 10119    1
# 10120    2
# 10121    2
# 10122    2
# 10123    1
# 10124    1
# 10125    1
# 10126    1
# Name: attrition, Length: 10127, dtype: int32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 24 columns):
# CLIENTNUM                   10127 non-null int64
# Attrition_Flag              10127 non-null object
# Customer_Age                10127 non-null int64
# Gender                      10127 non-null object
# Dependent_count             10127 non-null int64
# Education_Level             10127 non-null object
# Marital_Status              10127 non-null object
# Income_Category             10127 non-null object
# Card_Category               10127 non-null object
# Months_on_book              10127 non-null int64
# Total_Relationship_Count    10127 non-null int64
# Months_Inactive_12_mon      10127 non-null int64
# Contacts_Count_12_mon       10127 non-null int64
# Credit_Limit                10127 non-null float64
# Total_Revolving_Bal         10127 non-null int64
# Avg_Open_To_Buy             10127 non-null float64
# Total_Amt_Chng_Q4_Q1        10127 non-null float64
# ...

# %%
# Start of multivariate analysis

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, fmt=".2")
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Income_Category'],data['Credit_Limit']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Income_Category'],data['Total_Revolving_Bal']);
plt.show()

# %%
sns.scatterplot(data['Credit_Limit'],data['Total_Trans_Amt']);

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Customer_Age']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Dependent_count']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Months_on_book']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Total_Relationship_Count']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Months_Inactive_12_mon']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Contacts_Count_12_mon']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Credit_Limit']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Total_Revolving_Bal']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Avg_Open_To_Buy']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Total_Amt_Chng_Q4_Q1']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Total_Trans_Amt']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Total_Trans_Ct']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Total_Ct_Chng_Q4_Q1']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Avg_Utilization_Ratio']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Avg_Trans_Amt']);
plt.show()

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data['Attrition_Flag'],data['Avg_Trans_Amt_Chng_Q4_Q1']);
plt.show()

# %%
tab1 = pd.crosstab(data.Gender,data.Attrition_Flag,margins=True)
print(tab1)
print('-'*120)
tab = pd.crosstab(data.Gender,data.Attrition_Flag,normalize='index')
tab.plot(kind='bar',stacked=True,figsize=(17,9))
plt.legend(loc="upper left", bbox_to_anchor=(1,1));
# Out:
# Attrition_Flag  Attrited Customer  Existing Customer    All
# Gender
# F                             930               4428   5358
# M                             697               4072   4769
# All                          1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %%
tab1 = pd.crosstab(data.Education_Level ,data.Attrition_Flag,margins=True)
print(tab1)
print('-'*120)
tab = pd.crosstab(data.Education_Level,data.Attrition_Flag,normalize='index')
tab.plot(kind='bar',stacked=True,figsize=(17,9))
plt.legend(loc="upper left", bbox_to_anchor=(1,1));
# Out:
# Attrition_Flag   Attrited Customer  Existing Customer    All
# Education_Level
# College                        154                859   1013
# Doctorate                       95                356    451
# Graduate                       487               2641   3128
# High School                    306               1707   2013
# Post-Graduate                   92                424    516
# Uneducated                     237               1250   1487
# Unknown                        256               1263   1519
# All                           1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %%
tab1 = pd.crosstab(data.Marital_Status,data.Attrition_Flag,margins=True)
print(tab1)
print('-'*120)
tab = pd.crosstab(data.Marital_Status,data.Attrition_Flag,normalize='index')
tab.plot(kind='bar',stacked=True,figsize=(17,9))
plt.legend(loc="upper left", bbox_to_anchor=(1,1));
# Out:
# Attrition_Flag  Attrited Customer  Existing Customer    All
# Marital_Status
# Divorced                      121                627    748
# Married                       709               3978   4687
# Single                        668               3275   3943
# Unknown                       129                620    749
# All                          1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %%
tab1 = pd.crosstab(data.Income_Category,data.Attrition_Flag,margins=True)
print(tab1)
print('-'*120)
tab = pd.crosstab(data.Income_Category,data.Attrition_Flag,normalize='index')
tab.plot(kind='bar',stacked=True,figsize=(17,9))
plt.legend(loc="upper left", bbox_to_anchor=(1,1));
# Out:
# Attrition_Flag   Attrited Customer  Existing Customer    All
# Income_Category
# $120K +                        126                601    727
# $40K - $60K                    271               1519   1790
# $60K - $80K                    189               1213   1402
# $80K - $120K                   242               1293   1535
# Less than $40K                 612               2949   3561
# Unknown                        187                925   1112
# All                           1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %%
tab1 = pd.crosstab(data.Card_Category,data.Attrition_Flag,margins=True)
print(tab1)
print('-'*120)
tab = pd.crosstab(data.Card_Category,data.Attrition_Flag,normalize='index')
tab.plot(kind='bar',stacked=True,figsize=(17,9))
plt.legend(loc="upper left", bbox_to_anchor=(1,1));
# Out:
# Attrition_Flag  Attrited Customer  Existing Customer    All
# Card_Category
# Blue                         1519               7917   9436
# Gold                           21                 95    116
# Platinum                        5                 15     20
# Silver                         82                473    555
# All                          1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### plt.figure(figsize=(10,10))
# sns.boxplot(data['Location'],data['Price_x'],hue=data['Fuel_Type']);
# plt.show()

# %%
# Modelling

# %%
# Logistic Regression

# %%
data_ml=data.copy()

# %%
data_ml= data_ml.drop(['CLIENTNUM','Attrition_Flag','Avg_Trans_Amt','Avg_Trans_Amt_Chng_Q4_Q1'], axis=1)

# %%
data_ml.isnull().sum()
# Out:
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# attrition                   0
# dtype: int64

# %%
# independant variables
X = data_ml.drop(['attrition'], axis=1)

y = data_ml[['attrition']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
data_ml['Gender']=data_ml['Gender'].astype('category')
data_ml['Education_Level']=data_ml['Education_Level'].astype('category')
data_ml['Marital_Status']=data_ml['Marital_Status'].astype('category')
data_ml['Income_Category']=data_ml['Income_Category'].astype('category')
data_ml['Card_Category']=data_ml['Card_Category'].astype('category')

# %%
# data_ml= data_ml.drop(['CustomerID','ProductPitched'], axis=1)
# data_ml= pd.get_dummies(data_ml,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])
X_train= pd.get_dummies(X_train,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])
X_test= pd.get_dummies(X_test,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
# Libraries to tune model, get different metric scores and split data
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score,precision_score,recall_score
from sklearn import metrics
# Library to impute missing values
from sklearn.impute import KNNImputer
# Library to build a logistic regression model
from sklearn.linear_model import LogisticRegression
# Library to suppress the warning
import warnings
warnings.filterwarnings('ignore')

# %%
lr = LogisticRegression(random_state=1)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_bfr=cross_val_score(estimator=lr, X=X_train, y=y_train, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_bfr)
plt.show()

# %%
##  Function to calculate different metric scores of the model - Accuracy, Recall and Precision
def get_metrics_score(model,train,test,train_y,test_y,flag=True):
    '''
    model : classifier to predict values of X

    '''
    # defining an empty list to store train and test results
    score_list=[] 
    
    pred_train = model.predict(train)
    pred_test = model.predict(test)
    
    train_acc = model.score(train,train_y)
    test_acc = model.score(test,test_y)
    
    train_recall = metrics.recall_score(train_y,pred_train)
    test_recall = metrics.recall_score(test_y,pred_test)
    
    train_precision = metrics.precision_score(train_y,pred_train)
    test_precision = metrics.precision_score(test_y,pred_test)
    
    score_list.extend((train_acc,test_acc,train_recall,test_recall,train_precision,test_precision))
        
    # If the flag is set to True then only the following print statements will be displayed. The default value is set to True.
    if flag == True: 
        print("Accuracy on training set : ",model.score(train,train_y))
        print("Accuracy on test set : ",model.score(test,test_y))
        print("Recall on training set : ",metrics.recall_score(train_y,pred_train))
        print("Recall on test set : ",metrics.recall_score(test_y,pred_test))
        print("Precision on training set : ",metrics.precision_score(train_y,pred_train))
        print("Precision on test set : ",metrics.precision_score(test_y,pred_test))
    
    return score_list # returning the list with train and test scores
def make_confusion_matrix(model,y_actual,labels=[1, 0]):
    '''
    model : classifier to predict values of X
    y_actual : ground truth  
    
    '''
    y_predict = model.predict(X_test)
    cm=metrics.confusion_matrix( y_actual, y_predict, labels=[0, 1])
    df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No","Actual - Yes"]],
                  columns = [i for i in ['Predicted - No','Predicted - Yes']])
    group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
    labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=labels,fmt='')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Calculating different metrics
scores_LR = get_metrics_score(lr,X_train,X_test,y_train,y_test)

# creating confusion matrix
make_confusion_matrix(lr,y_test)
# Out:
# Accuracy on training set :  0.8876975169300225
# Accuracy on test set :  0.8910825929582099
# Recall on training set :  0.4863915715539947
# Recall on test set :  0.5020491803278688
# Precision on training set :  0.7241830065359477
# Precision on test set :  0.7357357357357357

# %%
from imblearn.over_sampling import SMOTE

# %%
print("Before UpSampling, counts of label 'Yes': {0}".format(y_train[y_train['attrition']==1].count()))
print("Before UpSampling, counts of label 'No': {0} \n".format(y_train[y_train['attrition']==0].count()))

sm = SMOTE(sampling_strategy = 1 ,k_neighbors = 5, random_state=1)   #Synthetic Minority Over Sampling Technique
X_train_over, y_train_over = sm.fit_resample(X_train, y_train)


print("After UpSampling, counts of label 'Yes': {0}".format(y_train_over[y_train_over['attrition']==1].count()))
print("After UpSampling, counts of label 'No': {0} \n".format(y_train_over[y_train_over['attrition']==0].count()))


print('After UpSampling, the shape of train_X: {0}'.format(X_train_over.shape))
print('After UpSampling, the shape of train_y: {0} \n'.format(y_train_over.shape))
# Out:
# Before UpSampling, counts of label 'Yes': attrition    1139
# dtype: int64
# Before UpSampling, counts of label 'No': attrition    5949
# dtype: int64
#
# After UpSampling, counts of label 'Yes': attrition    5949
# dtype: int64
# After UpSampling, counts of label 'No': attrition    5949
# dtype: int64
#
# After UpSampling, the shape of train_X: (11898, 37)
# After UpSampling, the shape of train_y: (11898, 1)

# %%
y_train[y_train['attrition']==1].sum()
# Out:
# attrition    1139
# dtype: int64

# %%
log_reg_over = LogisticRegression(random_state = 1)

# Training the basic logistic regression model with training set 
log_reg_over.fit(X_train_over,y_train_over)
# Out:
# LogisticRegression(random_state=1)

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_over=cross_val_score(estimator=log_reg_over, X=X_train_over, y=y_train_over, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_over)
plt.show()

# %%
#Calculating different metrics
get_metrics_score(log_reg_over,X_train_over,X_test,y_train_over,y_test)

# creating confusion matrix
make_confusion_matrix(log_reg_over,y_test)
# Out:
# Accuracy on training set :  0.8253487981173306
# Accuracy on test set :  0.8308654162553472
# Recall on training set :  0.8209783156833081
# Recall on test set :  0.7868852459016393
# Precision on training set :  0.8282177378327963
# Precision on test set :  0.4836272040302267

# %%
# Choose the type of classifier. 
lr_estimator = LogisticRegression(random_state=1,solver='saga')

# Grid of parameters to choose from
parameters = {'C': np.arange(0.1,1.1,0.1)}

# Run the grid search
grid_obj = GridSearchCV(lr_estimator, parameters, scoring='recall')
grid_obj = grid_obj.fit(X_train_over, y_train_over)

# Set the clf to the best combination of parameters
lr_estimator = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
lr_estimator.fit(X_train_over, y_train_over)
# Out:
# LogisticRegression(C=0.1, random_state=1, solver='saga')

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_over=cross_val_score(estimator=log_reg_over, X=X_train_over, y=y_train_over, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_over)
plt.show()

# %%
#Calculating different metrics
get_metrics_score(log_reg_over,X_train_over,X_test,y_train_over,y_test)

# creating confusion matrix
make_confusion_matrix(log_reg_over,y_test)
# Out:
# Accuracy on training set :  0.8253487981173306
# Accuracy on test set :  0.8308654162553472
# Recall on training set :  0.8209783156833081
# Recall on test set :  0.7868852459016393
# Precision on training set :  0.8282177378327963
# Precision on test set :  0.4836272040302267

# %%
# perform sampling

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state = 1)
X_train_un, y_train_un = rus.fit_resample(X_train, y_train)

# %%
print("Before downSampling, counts of label 'Yes': {0}".format(y_train[y_train['attrition']==1].count()))
print("Before downSampling, counts of label 'No': {0} \n".format(y_train[y_train['attrition']==0].count()))



print("After downSampling, counts of label 'Yes': {0}".format(y_train_un[y_train_un['attrition']==1].count()))
print("After downSampling, counts of label 'No': {0} \n".format(y_train_un[y_train_un['attrition']==0].count()))


print('After UpSampling, the shape of train_X: {0}'.format(X_train_un.shape))
print('After UpSampling, the shape of train_y: {0} \n'.format(y_train_un.shape))
# Out:
# Before downSampling, counts of label 'Yes': attrition    1139
# dtype: int64
# Before downSampling, counts of label 'No': attrition    5949
# dtype: int64
#
# After downSampling, counts of label 'Yes': attrition    1139
# dtype: int64
# After downSampling, counts of label 'No': attrition    1139
# dtype: int64
#
# After UpSampling, the shape of train_X: (2278, 37)
# After UpSampling, the shape of train_y: (2278, 1)

# %%
log_reg_under = LogisticRegression(random_state = 1)
log_reg_under.fit(X_train_un,y_train_un )
# Out:
# LogisticRegression(random_state=1)

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_under=cross_val_score(estimator=log_reg_under, X=X_train_un, y=y_train_un, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_under)
plt.show()

# %%
#Calculating different metrics
get_metrics_score(log_reg_under,X_train_un,X_test,y_train_un,y_test)


# creating confusion matrix
make_confusion_matrix(log_reg_under,y_test)
# Out:
# Accuracy on training set :  0.815188762071993
# Accuracy on test set :  0.8344850279697269
# Recall on training set :  0.8261633011413521
# Recall on test set :  0.8135245901639344
# Precision on training set :  0.8084192439862543
# Precision on test set :  0.4907292954264524

# %%
# Choose the type of classifier. 
lr_estimator_under = LogisticRegression(random_state=1,solver='saga')

# Grid of parameters to choose from
parameters = {'C': np.arange(0.1,1.1,0.1)}

# Run the grid search
grid_obj = GridSearchCV(lr_estimator_under, parameters, scoring='recall')
grid_obj = grid_obj.fit(X_train_un, y_train_un)

# Set the clf to the best combination of parameters
lr_estimator_under = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
lr_estimator_under.fit(X_train_un, y_train_un)
# Out:
# LogisticRegression(C=0.1, random_state=1, solver='saga')

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_under=cross_val_score(estimator=lr_estimator_under, X=X_train_un, y=y_train_un, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_under)
plt.show()

# %%
#Calculating different metrics
get_metrics_score(lr_estimator_under,X_train_un,X_test,y_train_un,y_test)


# creating confusion matrix
make_confusion_matrix(lr_estimator_under,y_test)
# Out:
# Accuracy on training set :  0.6185250219490781
# Accuracy on test set :  0.7834814083580125
# Recall on training set :  0.3678665496049166
# Recall on test set :  0.32991803278688525
# Precision on training set :  0.7376760563380281
# Precision on test set :  0.32723577235772355

# %%
# KNN imputing for unknown values

# %%
data_ml=data_ml.replace('Unknown',np.nan)

# %%
education = {'Uneducated':1, 'High School':2, 'College':3, 'Graduate':4, 'Post-Graduate':5, 'Doctorate':6}
data_ml['Education_Level']=data_ml['Education_Level'].map(education)
marital = {'Single':1, 'Married':2, 'Divorced':3}
data_ml['Marital_Status']=data_ml['Marital_Status'].map(marital)

income = {'$40K - $60K':1, '$80K - $120K':2, '$60K - $80K':3, '$120K +':4, 'Less than $40K':5}
data_ml['Income_Category']=data_ml['Income_Category'].map(income)

gender = {'F':1, 'M':2}
data_ml['Gender']=data_ml['Gender'].map(gender)

card = {'Blue':1, 'Silver':2, 'Gold':3, 'Platinum':4}
data_ml['Card_Category']=data_ml['Card_Category'].map(card)

# %%
# independant variables
X = data_ml.drop(['attrition'], axis=1)

y = data_ml[['attrition']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
X_train.isnull().sum()
# Out:
# Customer_Age                   0
# Gender                         0
# Dependent_count                0
# Education_Level             1058
# Marital_Status               525
# Income_Category              784
# Card_Category                  0
# Months_on_book                 0
# Total_Relationship_Count       0
# Months_Inactive_12_mon         0
# Contacts_Count_12_mon          0
# Credit_Limit                   0
# Total_Revolving_Bal            0
# Avg_Open_To_Buy                0
# Total_Amt_Chng_Q4_Q1           0
# Total_Trans_Amt                0
# Total_Trans_Ct                 0
# Total_Ct_Chng_Q4_Q1            0
# Avg_Utilization_Ratio          0
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# Customer_Age                  0
# Gender                        0
# Dependent_count               0
# Education_Level             461
# Marital_Status              224
# Income_Category             328
# Card_Category                 0
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                  0
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Amt_Chng_Q4_Q1          0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Total_Ct_Chng_Q4_Q1           0
# Avg_Utilization_Ratio         0
# dtype: int64

# %%
#Fit and transform the train data
X_train=pd.DataFrame(imputer.fit_transform(X_train),columns=X_train.columns)

#Transform the test data 
X_test=pd.DataFrame(imputer.transform(X_test),columns=X_test.columns)

# %%
## Function to inverse the encoding
def inverse_mapping(x,y):
    inv_dict = {v: k for k, v in x.items()}
    X_train[y] = np.round(X_train[y]).map(inv_dict).astype('category')
    X_test[y] = np.round(X_test[y]).map(inv_dict).astype('category')

# %%
inverse_mapping(education,'Education_Level')
inverse_mapping(marital,'Marital_Status')
inverse_mapping(income,'Income_Category')
inverse_mapping(card,'Card_Category')
inverse_mapping(gender,'Gender')

# %%
cols = X_train.select_dtypes(include=['object','category'])
for i in cols.columns:
    print(X_train[i].value_counts())
    print('*'*30)
# Out:
# F    3761
# M    3327
# Name: Gender, dtype: int64
# ******************************
# Graduate         2459
# High School      1603
# College          1262
# Uneducated       1079
# Post-Graduate     375
# Doctorate         310
# Name: Education_Level, dtype: int64
# ******************************
# Married     3657
# Single      2893
# Divorced     538
# Name: Marital_Status, dtype: int64
# ******************************
# Less than $40K    2552
# $60K - $80K       1352
# $40K - $60K       1265
# $80K - $120K      1213
# $120K +            706
# Name: Income_Category, dtype: int64
# ******************************
# Blue        6585
# Silver       409
# Gold          78
# Platinum      16
# Name: Card_Category, dtype: int64
# ******************************

# %%
X_train.isnull().sum()
# Out:
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
data_ml['Gender']=data_ml['Gender'].astype('category')
data_ml['Education_Level']=data_ml['Education_Level'].astype('category')
data_ml['Marital_Status']=data_ml['Marital_Status'].astype('category')
data_ml['Income_Category']=data_ml['Income_Category'].astype('category')
data_ml['Card_Category']=data_ml['Card_Category'].astype('category')

# %%
# data_ml= data_ml.drop(['CustomerID','ProductPitched'], axis=1)
# data_ml= pd.get_dummies(data_ml,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])
X_train= pd.get_dummies(X_train,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])
X_test= pd.get_dummies(X_test,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state = 1)
X_train_un, y_train_un = rus.fit_resample(X_train, y_train)

# %%
print("Before downSampling, counts of label 'Yes': {0}".format(y_train[y_train['attrition']==1].count()))
print("Before downSampling, counts of label 'No': {0} \n".format(y_train[y_train['attrition']==0].count()))



print("After downSampling, counts of label 'Yes': {0}".format(y_train_un[y_train_un['attrition']==1].count()))
print("After downSampling, counts of label 'No': {0} \n".format(y_train_un[y_train_un['attrition']==0].count()))


print('After UpSampling, the shape of train_X: {0}'.format(X_train_un.shape))
print('After UpSampling, the shape of train_y: {0} \n'.format(y_train_un.shape))
# Out:
# Before downSampling, counts of label 'Yes': attrition    1139
# dtype: int64
# Before downSampling, counts of label 'No': attrition    5949
# dtype: int64
#
# After downSampling, counts of label 'Yes': attrition    1139
# dtype: int64
# After downSampling, counts of label 'No': attrition    1139
# dtype: int64
#
# After UpSampling, the shape of train_X: (2278, 34)
# After UpSampling, the shape of train_y: (2278, 1)

# %%
log_reg_under = LogisticRegression(random_state = 1)
log_reg_under.fit(X_train_un,y_train_un )
# Out:
# LogisticRegression(random_state=1)

# %%
scoring='recall'
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=1)     #Setting number of splits equal to 5
cv_result_under=cross_val_score(estimator=log_reg_under, X=X_train_un, y=y_train_un, scoring=scoring, cv=kfold)
#Plotting boxplots for CV scores of model defined above
plt.boxplot(cv_result_under)
plt.show()

# %%
#Calculating different metrics
get_metrics_score(log_reg_under,X_train_un,X_test,y_train_un,y_test)


# creating confusion matrix
make_confusion_matrix(log_reg_under,y_test)
# Out:
# Accuracy on training set :  0.7870939420544337
# Accuracy on test set :  0.8038828562026983
# Recall on training set :  0.7787532923617209
# Recall on test set :  0.7868852459016393
# Precision on training set :  0.7919642857142857
# Precision on test set :  0.4383561643835616

# %%
## Function to create confusion matrix
def make_confusion_matrix(model,y_actual,labels=[1, 0]):
    '''
    model : classifier to predict values of X
    y_actual : ground truth  
    
    '''
    y_predict = model.predict(X_test)
    cm=metrics.confusion_matrix( y_actual, y_predict, labels=[0, 1])
    df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No","Actual - Yes"]],
                  columns = [i for i in ['Predicted - No','Predicted - Yes']])
    group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
    labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=labels,fmt='')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
##  Function to calculate recall score
def get_recall_score(model):
    '''
    model : classifier to predict values of X

    '''
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)
    print("Recall on training set : ",metrics.recall_score(y_train,pred_train))
    print("Recall on test set : ",metrics.recall_score(y_test,pred_test))

# %%
# modelling-pipeline

# %%
data_ml=data.copy()

# %%
data_ml= data_ml.drop(['CLIENTNUM','Attrition_Flag','Avg_Trans_Amt','Avg_Trans_Amt_Chng_Q4_Q1'], axis=1)

# %%
data_ml.isnull().sum()
# Out:
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# attrition                   0
# dtype: int64

# %%
# independant variables
X = data_ml.drop(['attrition'], axis=1)

y = data_ml[['attrition']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
data_ml['Gender']=data_ml['Gender'].astype('category')
data_ml['Education_Level']=data_ml['Education_Level'].astype('category')
data_ml['Marital_Status']=data_ml['Marital_Status'].astype('category')
data_ml['Income_Category']=data_ml['Income_Category'].astype('category')
data_ml['Card_Category']=data_ml['Card_Category'].astype('category')

# %%
# data_ml= data_ml.drop(['CustomerID','ProductPitched'], axis=1)
# data_ml= pd.get_dummies(data_ml,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])
X_train= pd.get_dummies(X_train,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])
X_test= pd.get_dummies(X_test,columns=['Gender','Education_Level','Marital_Status','Income_Category','Card_Category'])

# %%
print("Before UpSampling, counts of label 'Yes': {0}".format(y_train[y_train['attrition']==1].count()))
print("Before UpSampling, counts of label 'No': {0} \n".format(y_train[y_train['attrition']==0].count()))

sm = SMOTE(sampling_strategy = 1 ,k_neighbors = 5, random_state=1)   #Synthetic Minority Over Sampling Technique
X_train_over, y_train_over = sm.fit_resample(X_train, y_train)


print("After UpSampling, counts of label 'Yes': {0}".format(y_train_over[y_train_over['attrition']==1].count()))
print("After UpSampling, counts of label 'No': {0} \n".format(y_train_over[y_train_over['attrition']==0].count()))


print('After UpSampling, the shape of train_X: {0}'.format(X_train_over.shape))
print('After UpSampling, the shape of train_y: {0} \n'.format(y_train_over.shape))
# Out:
# Before UpSampling, counts of label 'Yes': attrition    1139
# dtype: int64
# Before UpSampling, counts of label 'No': attrition    5949
# dtype: int64
#
# After UpSampling, counts of label 'Yes': attrition    5949
# dtype: int64
# After UpSampling, counts of label 'No': attrition    5949
# dtype: int64
#
# After UpSampling, the shape of train_X: (11898, 37)
# After UpSampling, the shape of train_y: (11898, 1)

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state = 1)
X_train_un, y_train_un = rus.fit_resample(X_train, y_train)

# %%
print("Before downSampling, counts of label 'Yes': {0}".format(y_train[y_train['attrition']==1].count()))
print("Before downSampling, counts of label 'No': {0} \n".format(y_train[y_train['attrition']==0].count()))



print("After downSampling, counts of label 'Yes': {0}".format(y_train_un[y_train_un['attrition']==1].count()))
print("After downSampling, counts of label 'No': {0} \n".format(y_train_un[y_train_un['attrition']==0].count()))


print('After UpSampling, the shape of train_X: {0}'.format(X_train_un.shape))
print('After UpSampling, the shape of train_y: {0} \n'.format(y_train_un.shape))
# Out:
# Before downSampling, counts of label 'Yes': attrition    1139
# dtype: int64
# Before downSampling, counts of label 'No': attrition    5949
# dtype: int64
#
# After downSampling, counts of label 'Yes': attrition    1139
# dtype: int64
# After downSampling, counts of label 'No': attrition    1139
# dtype: int64
#
# After UpSampling, the shape of train_X: (2278, 37)
# After UpSampling, the shape of train_y: (2278, 1)

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier)
from xgboost import XGBClassifier
# Libraries to tune model, get different metric scores, and split data
from sklearn import metrics
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

# %%
models = []  # Empty list to store all the models

# Appending pipelines for each model into the list
models.append(
    (
        "BC",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("bag_class", BaggingClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "RF",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("random_forest", RandomForestClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "GBM",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("gradient_boosting", GradientBoostingClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "ADB",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("adaboost", AdaBoostClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "XGB",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("xgboost", XGBClassifier(random_state=1,eval_metric='logloss')),
            ]
        ),
    )
)
models.append(
    (
        "DTREE",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("decision_tree", DecisionTreeClassifier(random_state=1)),
            ]
        ),
    )
)

results = []  # Empty list to store all model's CV scores
names = []  # Empty list to store name of the models

# loop through all models to get the mean cross validated score
for name, model in models:
    scoring = "recall"
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    cv_result = cross_val_score(
        estimator=model, X=X_train, y=y_train, scoring=scoring, cv=kfold
    )
    results.append(cv_result)
    names.append(name)
    print("{}: {}".format(name, cv_result.mean() * 100))
# Out:
# BC: 81.82664811809259
# RF: 76.73506453358065
# GBM: 84.10812272973182
# ADB: 83.9315248473607
# XGB: 88.76265553752222
# DTREE: 77.79271968467422

# %%
# run with oversampled data

# %%
models = []  # Empty list to store all the models

# Appending pipelines for each model into the list
models.append(
    (
        "BC",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("bag_class", BaggingClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "RF",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("random_forest", RandomForestClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "GBM",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("gradient_boosting", GradientBoostingClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "ADB",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("adaboost", AdaBoostClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "XGB",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("xgboost", XGBClassifier(random_state=1,eval_metric='logloss')),
            ]
        ),
    )
)
models.append(
    (
        "DTREE",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("decision_tree", DecisionTreeClassifier(random_state=1)),
            ]
        ),
    )
)

results = []  # Empty list to store all model's CV scores
names = []  # Empty list to store name of the models

# loop through all models to get the mean cross validated score
for name, model in models:
    scoring = "recall"
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    cv_result = cross_val_score(
        estimator=model, X=X_train_over, y=y_train_over, scoring=scoring, cv=kfold
    )
    results.append(cv_result)
    names.append(name)
    print("{}: {}".format(name, cv_result.mean() * 100))
# Out:
# BC: 96.63803351449916
# RF: 98.30223830490985
# GBM: 97.3439865433137
# ADB: 96.6381748662459
# XGB: 98.43667795124779
# DTREE: 95.34373211016955

# %%
models = []  # Empty list to store all the models

# Appending pipelines for each model into the list
models.append(
    (
        "BC",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("bag_class", BaggingClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "RF",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("random_forest", RandomForestClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "GBM",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("gradient_boosting", GradientBoostingClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "ADB",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("adaboost", AdaBoostClassifier(random_state=1)),
            ]
        ),
    )
)
models.append(
    (
        "XGB",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("xgboost", XGBClassifier(random_state=1,eval_metric='logloss')),
            ]
        ),
    )
)
models.append(
    (
        "DTREE",
        Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("decision_tree", DecisionTreeClassifier(random_state=1)),
            ]
        ),
    )
)

results = []  # Empty list to store all model's CV scores
names = []  # Empty list to store name of the models

# loop through all models to get the mean cross validated score
for name, model in models:
    scoring = "recall"
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    cv_result = cross_val_score(
        estimator=model, X=X_train_un, y=y_train_un, scoring=scoring, cv=kfold
    )
    results.append(cv_result)
    names.append(name)
    print("{}: {}".format(name, cv_result.mean() * 100))
# Out:
# BC: 91.04722157817451
# RF: 93.50413478630497
# GBM: 94.82185640312235
# ADB: 93.50529407218487
# XGB: 94.99806785686683
# DTREE: 86.21995517427929

# %%
# plot results of over sampled models

# %%
# Plotting boxplots for CV scores of all models defined above
fig = plt.figure(figsize=(10, 7))

fig.suptitle("Algorithm Comparison")
ax = fig.add_subplot(111)

plt.boxplot(results)
ax.set_xticklabels(names)

plt.show()

# %%
##  Function to calculate different metric scores of the model - Accuracy, Recall and Precision
def get_metrics_score(model, flag=True):
    """
    model: classifier to predict values of X

    """
    # defining an empty list to store train and test results
    score_list = []

    pred_train = model.predict(X_train_over)
    pred_test = model.predict(X_test)

    train_acc = model.score(X_train_over, y_train_over)
    test_acc = model.score(X_test, y_test)

    train_recall = metrics.recall_score(y_train_over, pred_train)
    test_recall = metrics.recall_score(y_test, pred_test)

    train_precision = metrics.precision_score(y_train_over, pred_train)
    test_precision = metrics.precision_score(y_test, pred_test)

    score_list.extend(
        (
            train_acc,
            test_acc,
            train_recall,
            test_recall,
            train_precision,
            test_precision,
        )
    )

    # If the flag is set to True then only the following print statements will be dispayed. The default value is set to True.
    if flag == True:
        print("Accuracy on training set : ", model.score(X_train_over, y_train_over))
        print("Accuracy on test set : ", model.score(X_test, y_test))
        print("Recall on training set : ", metrics.recall_score(y_train_over, pred_train))
        print("Recall on test set : ", metrics.recall_score(y_test, pred_test))
        print(
            "Precision on training set : ", metrics.precision_score(y_train_over, pred_train)
        )
        print("Precision on test set : ", metrics.precision_score(y_test, pred_test))

    return score_list  # returning the list with train and test scores

# %%
## Function to create confusion matrix
def make_confusion_matrix(model, y_actual, labels=[1, 0]):
    """
    model: classifier to predict values of X
    y_actual: ground truth

    """
    y_predict = model.predict(X_test)
    cm = metrics.confusion_matrix(y_actual, y_predict, labels=[0, 1])
    df_cm = pd.DataFrame(
        cm,
        index=[i for i in ["Actual - No", "Actual - Yes"]],
        columns=[i for i in ["Predicted - No", "Predicted - Yes"]],
    )
    group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in cm.flatten() / np.sum(cm)]
    labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(2, 2)
    plt.figure(figsize=(10, 7))
    sns.heatmap(df_cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %%
#Hypertuning on RF

# %%
pipe = make_pipeline(StandardScaler(), RandomForestClassifier(random_state=1))
# Parameter grid to pass in RandomSearchCV
param_grid = {
#     "class_weight": [{0: 0.19, 1: 0.81}],
    "randomforestclassifier__n_estimators": [50,100,150,200,300],
    "randomforestclassifier__min_samples_leaf": np.arange(5, 10),
    "randomforestclassifier__max_features": np.arange( 0.3,0.7, 0.1),
    "randomforestclassifier__max_samples": np.arange( 0.3,0.7, 0.1),
    
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Calling GridSearchCV
RFRS_cv = RandomizedSearchCV(estimator=pipe, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1)


# Fitting parameters in GridSeachCV
RFRS_cv.fit(X_train_over, y_train_over)

print(
    "Best Parameters:{} \nScore: {}".format(RFRS_cv.best_params_, RFRS_cv.best_score_)
)
# Out:
# Best Parameters:{'randomforestclassifier__n_estimators': 200, 'randomforestclassifier__min_samples_leaf': 5, 'randomforestclassifier__max_samples': 0.6000000000000001, 'randomforestclassifier__max_features': 0.5}
# Score: 0.9736111837502032

# %%
# Creating new pipeline with best parameters
RFRS_tuned = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        (
            "RFRS",
            RandomForestClassifier(
                random_state=1,
                n_estimators=200,
                min_samples_leaf=5,
                max_features=0.5,
                max_samples=0.6,
                
            ),
        ),
    ]
)
# Fit the model on training data
RFRS_tuned.fit(X_train_over, y_train_over)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('RFRS',
#                  RandomForestClassifier(max_features=0.5, max_samples=0.6,
#                                         min_samples_leaf=5, n_estimators=200,
#                                         random_state=1))])

# %%
# Calculating different metrics
get_metrics_score(RFRS_tuned)

# Creating confusion matrix
make_confusion_matrix(RFRS_tuned, y_test)
# Out:
# Accuracy on training set :  0.9840309295679946
# Accuracy on test set :  0.9512997696610728
# Recall on training set :  0.9915952260884182
# Recall on test set :  0.8975409836065574
# Precision on training set :  0.9768173538665342
# Precision on test set :  0.8171641791044776

# %%
pipe = make_pipeline(StandardScaler(), RandomForestClassifier(random_state=1))
# Parameter grid to pass in RandomSearchCV
param_grid = {
#     "class_weight": [{0: 0.19, 1: 0.81}],
    "randomforestclassifier__n_estimators": [200,250],
    "randomforestclassifier__min_samples_leaf": [3,5],
    "randomforestclassifier__max_features": [0.4,0.5],
    "randomforestclassifier__max_samples": [0.4,0.5],
    
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Calling GridSearchCV
RFGS_cv = GridSearchCV(estimator=pipe, param_grid=param_grid, scoring=scorer, cv=5, n_jobs = -1)


# Fitting parameters in GridSeachCV
RFGS_cv.fit(X_train_over, y_train_over)

print(
    "Best Parameters:{} \nScore: {}".format(RFGS_cv.best_params_, RFGS_cv.best_score_)
)
# Out:
# Best Parameters:{'randomforestclassifier__max_features': 0.4, 'randomforestclassifier__max_samples': 0.4, 'randomforestclassifier__min_samples_leaf': 3, 'randomforestclassifier__n_estimators': 250}
# Score: 0.9746202938702815

# %%
# Creating new pipeline with best parameters
RFGS_tuned = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        (
            "RFGS",
            RandomForestClassifier(
                random_state=1,
                n_estimators=250,
                min_samples_leaf=3,
                max_features=0.4,
                max_samples=0.4,
                
            ),
        ),
    ]
)
# Fit the model on training data
RFGS_tuned.fit(X_train_over, y_train_over)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('RFGS',
#                  RandomForestClassifier(max_features=0.4, max_samples=0.4,
#                                         min_samples_leaf=3, n_estimators=250,
#                                         random_state=1))])

# %%
# Calculating different metrics
get_metrics_score(RFGS_tuned)

# Creating confusion matrix
make_confusion_matrix(RFGS_tuned, y_test)
# Out:
# Accuracy on training set :  0.9852075979156161
# Accuracy on test set :  0.9519578808818691
# Recall on training set :  0.993108085392503
# Recall on test set :  0.9016393442622951
# Precision on training set :  0.9776601025980474
# Precision on test set :  0.8178438661710037

# %%
RFGS_tuned.steps[1][1].feature_importances_
# Out:
# array([1.87119428e-02, 3.47250997e-03, 9.27119938e-03, 5.16118211e-02,
#        5.30342294e-03, 4.65613317e-03, 1.54457244e-02, 1.19414807e-01,
#        1.58684164e-02, 4.76894271e-02, 2.51088393e-01, 2.66822195e-01,
#        8.22561315e-02, 4.01573829e-02, 6.23482920e-03, 1.53637356e-02,
#        1.10465448e-03, 2.83819000e-04, 4.01086578e-03, 2.43776972e-03,
#        2.61233597e-04, 1.86891389e-03, 9.87609996e-04, 1.16595464e-03,
#        1.76302807e-02, 3.26498680e-03, 1.24322194e-03, 3.74566486e-04,
#        1.63855339e-03, 3.33357226e-03, 1.77124736e-03, 1.26007368e-03,
#        9.28979716e-04, 1.89505245e-03, 1.46004525e-04, 0.00000000e+00,
#        1.02456768e-03])

# %%
# importances = RFGS_tuned.feature_importances_
importances = RFGS_tuned.steps[1][1].feature_importances_
indices = np.argsort(importances)
feature_names = list(X_train.columns)

plt.figure(figsize=(12,12))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='violet', align='center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
#Hypertuning on GB

# %%
pipe = make_pipeline(StandardScaler(), GradientBoostingClassifier(random_state=1))
# Parameter grid to pass in RandomSearchCV
param_grid = {
#     "class_weight": [{0: 0.19, 1: 0.81}],
    "gradientboostingclassifier__n_estimators": [50,100,150,200],
    "gradientboostingclassifier__min_samples_leaf": np.arange(5, 10),
    "gradientboostingclassifier__max_features": np.arange( 0.3,0.7, 0.1),
    "gradientboostingclassifier__subsample": np.arange( 0.5,0.7, 0.1),
    "gradientboostingclassifier__max_depth": [3,5,7], 
         
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Calling GridSearchCV
GBRS_cv = RandomizedSearchCV(estimator=pipe, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1)


# Fitting parameters in GridSeachCV
GBRS_cv.fit(X_train_over, y_train_over)

print(
    "Best Parameters:{} \nScore: {}".format(GBRS_cv.best_params_, GBRS_cv.best_score_)
)
# Out:
# Best Parameters:{'gradientboostingclassifier__subsample': 0.5, 'gradientboostingclassifier__n_estimators': 50, 'gradientboostingclassifier__min_samples_leaf': 5, 'gradientboostingclassifier__max_features': 0.5, 'gradientboostingclassifier__max_depth': 7}
# Score: 0.9642012566170287

# %%
# Creating new pipeline with best parameters
GBRS_tuned = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        (
            "GBRS",
            GradientBoostingClassifier(
                random_state=1,
                n_estimators=50,
                min_samples_leaf=5,
                max_features=0.5,
                subsample=0.5,
                max_depth=7,
                
            ),
        ),
    ]
)
# Fit the model on training data
GBRS_tuned.fit(X_train_over, y_train_over)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('GBRS',
#                  GradientBoostingClassifier(max_depth=7, max_features=0.5,
#                                             min_samples_leaf=5, n_estimators=50,
#                                             random_state=1, subsample=0.5))])

# %%
# Calculating different metrics
get_metrics_score(GBRS_tuned)

# Creating confusion matrix
make_confusion_matrix(GBRS_tuned, y_test)
# Out:
# Accuracy on training set :  0.9930240376533871
# Accuracy on test set :  0.9615004935834156
# Recall on training set :  0.9952933266095142
# Recall on test set :  0.889344262295082
# Precision on training set :  0.9907965194109772
# Precision on test set :  0.8732394366197183

# %%
pipe = make_pipeline(StandardScaler(),  GradientBoostingClassifier(random_state=1))
# Parameter grid to pass in RandomSearchCV
param_grid = {
#     "class_weight": [{0: 0.19, 1: 0.81}],
    "gradientboostingclassifier__n_estimators": [10,30,50],
    "gradientboostingclassifier__min_samples_leaf": [3,5],
    "gradientboostingclassifier__max_features": [0.4,0.5],
    "gradientboostingclassifier__subsample": [0.4,0.5],
    "gradientboostingclassifier__max_depth": [7,9], 
    
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Calling GridSearchCV
GBGS_cv = GridSearchCV(estimator=pipe, param_grid=param_grid, scoring=scorer, cv=5, n_jobs = -1)


# Fitting parameters in GridSeachCV
GBGS_cv.fit(X_train_over, y_train_over)

print(
    "Best Parameters:{} \nScore: {}".format(GBGS_cv.best_params_, GBGS_cv.best_score_)
)
# Out:
# Best Parameters:{'gradientboostingclassifier__max_depth': 9, 'gradientboostingclassifier__max_features': 0.4, 'gradientboostingclassifier__min_samples_leaf': 5, 'gradientboostingclassifier__n_estimators': 30, 'gradientboostingclassifier__subsample': 0.5}
# Score: 0.9732768868691295

# %%
# Creating new pipeline with best parameters
GBGS_tuned = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        (
            "GBGS",
            GradientBoostingClassifier(
                 n_estimators=30,
                min_samples_leaf=5,
                max_features=0.4,
                subsample=0.5,
                max_depth=9,
                
            ),
        ),
    ]
)
# Fit the model on training data
GBGS_tuned.fit(X_train_over, y_train_over)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('GBGS',
#                  GradientBoostingClassifier(max_depth=9, max_features=0.4,
#                                             min_samples_leaf=5, n_estimators=30,
#                                             subsample=0.5))])

# %%
# Calculating different metrics
get_metrics_score(GBGS_tuned)

# Creating confusion matrix
make_confusion_matrix(GBGS_tuned, y_test)
# Out:
# Accuracy on training set :  0.9933602286098504
# Accuracy on test set :  0.9601842711418229
# Recall on training set :  0.9968061859135989
# Recall on test set :  0.8934426229508197
# Precision on training set :  0.989983305509182
# Precision on test set :  0.8633663366336634

# %%
importances = GBGS_tuned.steps[1][1].feature_importances_
indices = np.argsort(importances)
feature_names = list(X_train.columns)

plt.figure(figsize=(12,12))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='violet', align='center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
#Hypertuning on XGB

# %%
pipe = make_pipeline(StandardScaler(), XGBClassifier(random_state=1,eval_metric='logloss'))
# Parameter grid to pass in RandomSearchCV
param_grid = {
#     "class_weight": [{0: 0.19, 1: 0.81}],
            'xgbclassifier__n_estimators':np.arange(50,300,50),
            'xgbclassifier__learning_rate':[0.01,0.1,0.2,0.05],
            'xgbclassifier__gamma':[0,1,3,5],
            'xgbclassifier__subsample':[0.7,0.8,0.9,1],
            'xgbclassifier__max_depth':np.arange(1,10,1),
            'xgbclassifier__reg_lambda':[0,1,2,5,10],
    }

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Calling GridSearchCV
XGRS_cv = RandomizedSearchCV(estimator=pipe, param_distributions=param_grid, n_iter=50, scoring=scorer, cv=5, random_state=1)


# Fitting parameters in GridSeachCV
XGRS_cv.fit(X_train_over, y_train_over)

print(
    "Best Parameters:{} \nScore: {}".format(XGRS_cv.best_params_, XGRS_cv.best_score_)
)
# Out:
# Best Parameters:{'xgbclassifier__subsample': 0.9, 'xgbclassifier__reg_lambda': 0, 'xgbclassifier__n_estimators': 200, 'xgbclassifier__max_depth': 6, 'xgbclassifier__learning_rate': 0.01, 'xgbclassifier__gamma': 0}
# Score: 0.9675594914164151

# %%
# Creating new pipeline with best parameters
XGRS_tuned = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        (
            "XGRS",
            XGBClassifier(
                random_state=1,
                n_estimators=200,
                learning_rate=0.01,
                gamma=0,
                subsample=0.9,
                max_depth=6,
                reg_lambda=0,
                
            ),
        ),
    ]
)
# Fit the model on training data
XGRS_tuned.fit(X_train_over, y_train_over)
# Out:
# [17:09:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('XGRS',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, gpu_id=-1,
#                                importance_type='gain',
#                                interaction_constraints='', learning_rate=0.01,
#                                max_delta_step=0, max_depth=6,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=200,
# ...

# %%
# Calculating different metrics
get_metrics_score(XGRS_tuned)

# Creating confusion matrix
make_confusion_matrix(XGRS_tuned, y_test)
# Out:
# Accuracy on training set :  0.9757102033955286
# Accuracy on test set :  0.9437314906219151
# Recall on training set :  0.9843671205244579
# Recall on test set :  0.8934426229508197
# Precision on training set :  0.9676140118968936
# Precision on test set :  0.7855855855855856

# %%
pipe = make_pipeline(StandardScaler(),  XGBClassifier(random_state=1))
# Parameter grid to pass in RandomSearchCV
param_grid = {
#     "class_weight": [{0: 0.19, 1: 0.81}],
            'xgbclassifier__n_estimators':[100,200],
            'xgbclassifier__learning_rate':[0.01,0.001],
            'xgbclassifier__gamma':[0,0.5],
            'xgbclassifier__subsample':[0.85,0.9],
            'xgbclassifier__max_depth':[5,6],
            'xgbclassifier__reg_lambda':[0,0.5], 
    
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Calling GridSearchCV
XGGS_cv = GridSearchCV(estimator=pipe, param_grid=param_grid, scoring=scorer, cv=5, n_jobs = -1)


# Fitting parameters in GridSeachCV
XGGS_cv.fit(X_train_over, y_train_over)

print(
    "Best Parameters:{} \nScore: {}".format(XGGS_cv.best_params_, XGGS_cv.best_score_)
)
# Out:
# [17:31:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best Parameters:{'xgbclassifier__gamma': 0, 'xgbclassifier__learning_rate': 0.01, 'xgbclassifier__max_depth': 6, 'xgbclassifier__n_estimators': 200, 'xgbclassifier__reg_lambda': 0, 'xgbclassifier__subsample': 0.85}
# Score: 0.9687359620046504

# %%
# Creating new pipeline with best parameters
XGGS_tuned = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        (
            "XGGS",
            XGBClassifier(
                random_state=1,
          n_estimators=200,
learning_rate=0.01,
            gamma=0,
            subsample=0.85,
            max_depth=6,
            reg_lambda=0, 
    
                                
            ),
        ),
    ]
)
# Fit the model on training data
XGGS_tuned.fit(X_train_over, y_train_over)
# Out:
# [17:32:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('XGGS',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, gpu_id=-1,
#                                importance_type='gain',
#                                interaction_constraints='', learning_rate=0.01,
#                                max_delta_step=0, max_depth=6,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=200,
# ...

# %%
# Calculating different metrics
get_metrics_score(XGGS_tuned)

# Creating confusion matrix
make_confusion_matrix(XGGS_tuned, y_test)
# Out:
# Accuracy on training set :  0.9754580601781812
# Accuracy on test set :  0.9450477130635078
# Recall on training set :  0.9841990250462263
# Recall on test set :  0.8934426229508197
# Precision on training set :  0.9672889476292748
# Precision on test set :  0.7912885662431942

# %%
importances = XGGS_tuned.steps[1][1].feature_importances_
indices = np.argsort(importances)
feature_names = list(X_train.columns)

plt.figure(figsize=(12,12))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='violet', align='center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# defining list of models
models = [RFRS_tuned,RFGS_tuned,GBRS_tuned,GBGS_tuned,XGRS_tuned,XGGS_tuned]

# defining empty lists to add train and test results
acc_train = []
acc_test = []
recall_train = []
recall_test = []
precision_train = []
precision_test = []

# looping through all the models to get the metrics score - Accuracy, Recall and Precision
for model in models:

    j = get_metrics_score(model, False)
    acc_train.append(j[0])
    acc_test.append(j[1])
    recall_train.append(j[2])
    recall_test.append(j[3])
    precision_train.append(j[4])
    precision_test.append(j[5])

# %%
comparison_frame = pd.DataFrame(
    {
        "Model": [
            "RandomForest with RandomizedSearchCV",
            "RandomForest with GridSearchCV",
            "Gradient Boost with RandomizedSearchCV",
            "Gradient Boost with GridSearchCV",
            "XGBoost with RandomizedSearchCV",
            "XGBoost with GridSearchCV"
    
        ],
        "Train_Accuracy": acc_train,
        "Test_Accuracy": acc_test,
        "Train_Recall": recall_train,
        "Test_Recall": recall_test,
        "Train_Precision": precision_train,
        "Test_Precision": precision_test,
    }
)

# Sorting models in decreasing order of test recall
comparison_frame.sort_values(by="Test_Recall", ascending=False)
# Out:
#                                     Model  Train_Accuracy  Test_Accuracy  \
# 1          RandomForest with GridSearchCV        0.985208       0.951958
# 0    RandomForest with RandomizedSearchCV        0.984031       0.951300
# 3        Gradient Boost with GridSearchCV        0.993360       0.960184
# 4         XGBoost with RandomizedSearchCV        0.975710       0.943731
# 5               XGBoost with GridSearchCV        0.975458       0.945048
# 2  Gradient Boost with RandomizedSearchCV        0.993024       0.961500
#
#    Train_Recall  Test_Recall  Train_Precision  Test_Precision
# 1      0.993108     0.901639         0.977660        0.817844
# 0      0.991595     0.897541         0.976817        0.817164
# 3      0.996806     0.893443         0.989983        0.863366
# 4      0.984367     0.893443         0.967614        0.785586
# 5      0.984199     0.893443         0.967289        0.791289
# 2      0.995293     0.889344         0.990797        0.873239

# %%
# RandomForest with gridsearch gives best recall and will be the proposed model to use in production
